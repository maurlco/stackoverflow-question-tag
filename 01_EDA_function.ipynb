# %%
import matplotlib.pyplot as plt
import pandas as pd
#from collections import defaultdict
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from wordcloud import WordCloud

from bs4 import BeautifulSoup
from pandarallel import pandarallel

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
pandarallel.initialize(progress_bar=True,
                        nb_workers=6,
                        #verbose=1
                       )
# Out:
# INFO: Pandarallel will run on 6 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
df = pd.read_csv('/Users/maurelco/Developer/Python/Projet 4/data/Cleaned/df_cleaned.csv')

# %%
df
# Out:
#                                                    Title  \
# 0      giving a unix process exclusive rw access to a...
# 1               automatic repaint when minimizing window
# 2      is man-in-the-middle attack a security threat ...
# 3          managing data access in a simple winforms app
# 4                                render basic html view?
# ...                                                  ...
# 49995  bypass vertica error 3326: execution time exce...
# 49996  a conflicting conditional operation is current...
# 49997      problem in lr_find() in pytorch fastai course
# 49998     jsonpatch escape slash '/' from jsonpatch+json
# 49999  org.gradle.internal.resolve.artifactnotfoundex...
#
#                                                     Body  \
# 0      is there a way to sandbox a linux process into...
# 1      i have a jframe, with two panels, in one panel...
# 2      i am no expert in network security, so pardon ...
# 3      i have a simple winforms data entry app that u...
# 4      i have a basic node.js app that i am trying to...
# ...                                                  ...
# 49995  using the ssis tool and ole db, we are downloa...
# 49996  using s3fs, i am uploading a file to the alrea...
# 49997  while following the jupyter notebooks for the ...
# 49998  i've below json and i wanted to update few fie...
# 49999  i am using 15.0.1 version of firebase and goog...
#
#                                                     Tags
# 0             <linux><ubuntu><process><sandbox><selinux>
# 1                <java><graphics><jframe><jpanel><paint>
# 2      <security><ssh><ssh-keys><openssh><man-in-the-...
# 3       <c#><winforms><sqlite><datatable><sqlconnection>
# 4          <javascript><html><node.js><mongodb><express>
# ...                                                  ...
# 49995  <sql-server><ssas><oledb><sql-server-data-tool...
# 49996  <python><amazon-web-services><amazon-s3><boto3...
# 49997  <python><machine-learning><deep-learning><pyto...
# 49998         <java><json><rest><json-patch><http-patch>
# 49999  <android><android-studio><android-gradle-plugi...
#
# [50000 rows x 3 columns]

# %% [markdown]
# ### 1. Exploratory Analysis

# %%
df['Body'].sample(1)
# Out:
# 43980    ok, this is going to be my beating a dying hor...
# Name: Body, dtype: object

# %%
document_1 = df['Body'].iloc[1227]
document_1
# Out:
# 'i miss it so much (used it a lot in c#). can you do it in c++?\n'

# %%
tag_1 = df['Tags'].iloc[1227]
tag_1
# Out:
# '<c++><visual-studio><visual-studio-2008><pragma><readability>'

# %% [markdown]
# #### ---- Searching the best Regex for Tokenisation ----

# %%
tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+') # [a-zA-Z0-9_\+#]+
doc_tokens = tokenizer.tokenize(document_1)

# %%
doc_tokens
# Out:
# ['i',
#  'miss',
#  'it',
#  'so',
#  'much',
#  'used',
#  'it',
#  'a',
#  'lot',
#  'in',
#  'c#',
#  'can',
#  'you',
#  'do',
#  'it',
#  'in',
#  'c++']

# %%
english_stop_words=nltk.corpus.stopwords.words('English')
cleaned_tokens_list = [word for word in doc_tokens if word not in english_stop_words]

# %%
cleaned_tokens_list
# Out:
# ['miss', 'much', 'used', 'lot', 'c#', 'c++']

# %%
len(cleaned_tokens_list)
# Out:
# 6

# %%
len(set(cleaned_tokens_list))
# Out:
# 6

# %% [markdown]
# #### ---- defining the best word standardisation ----

# %%
trans_lem = WordNetLemmatizer()
trans_text_lem = [trans_lem.lemmatize(word) for word in cleaned_tokens_list]
trans_text_lem
# Out:
# ['miss', 'much', 'used', 'lot', 'c#', 'c++']

# %%
trans_stem = SnowballStemmer("english")
trans_text_stem = [trans_stem.stem(word) for word in cleaned_tokens_list]
trans_text_stem
# Out:
# ['miss', 'much', 'use', 'lot', 'c#', 'c++']

# %%
len(trans_text_lem)
# Out:
# 6

# %%
len(set(trans_text_lem))
# Out:
# 6

# %%
len(set(trans_text_stem))
# Out:
# 6

# %%
trans_text_stem_no_duplicates = sorted(set(trans_text_stem))
trans_text_stem_no_duplicates
# Out:
# ['c#', 'c++', 'lot', 'miss', 'much', 'use']

# %% [markdown]
# ### 2. Text preprocessing function

# %%
def display_tokens_info(tokens):
    """display info about corpus"""
    print(f"nb tokens {len(tokens)}, nb tokens uniques {len(set(tokens))}")
    print(tokens[:30])

# %%
def process_text(doc,
                   rejoin=True,
                    stem_or_lem = 2,
                 ) :
    """function of text processing

    positional arguments:
    ----------------------
    doc: str : the document (aka a text in str format) to process

    opt arguments:
    ---------------------
    rejoin: bool : if True return a string else return a list of tokens
    stem_or_lem: 1 : if 1 run the Stemmer transformation, if 2 run Lemmer trans

    return:
    --------------------
    a string (if rejoin is True) or a list of tokens
    """

    #tokenizer
    tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+')
    raw_tokens_list = tokenizer.tokenize(doc)

    # stop words:
    english_stop_words=nltk.corpus.stopwords.words('English')
    cleaned_tokens_list = [word for word in raw_tokens_list if word not in english_stop_words]

    #############################################################################################

    #lemmatizer
    if stem_or_lem == 1:
        trans = SnowballStemmer("english")
        trans_text = [trans.stem(word) for word in cleaned_tokens_list]
    if stem_or_lem == 2:
        trans = WordNetLemmatizer()
        trans_text = [trans.lemmatize(word) for word in cleaned_tokens_list]
    else:
        trans_text = cleaned_tokens_list

        #############################################################################################


    if rejoin:
        return " ".join(trans_text)

    return trans_text

# %%
def final_clean(doc):
    new_doc = process_text(doc,
                           rejoin=True,
                           stem_or_lem= 2,
                           )
    return new_doc

# %%
df
# Out:
#                                                    Title  \
# 0      giving a unix process exclusive rw access to a...
# 1               automatic repaint when minimizing window
# 2      is man-in-the-middle attack a security threat ...
# 3          managing data access in a simple winforms app
# 4                                render basic html view?
# ...                                                  ...
# 49995  bypass vertica error 3326: execution time exce...
# 49996  a conflicting conditional operation is current...
# 49997      problem in lr_find() in pytorch fastai course
# 49998     jsonpatch escape slash '/' from jsonpatch+json
# 49999  org.gradle.internal.resolve.artifactnotfoundex...
#
#                                                     Body  \
# 0      is there a way to sandbox a linux process into...
# 1      i have a jframe, with two panels, in one panel...
# 2      i am no expert in network security, so pardon ...
# 3      i have a simple winforms data entry app that u...
# 4      i have a basic node.js app that i am trying to...
# ...                                                  ...
# 49995  using the ssis tool and ole db, we are downloa...
# 49996  using s3fs, i am uploading a file to the alrea...
# 49997  while following the jupyter notebooks for the ...
# 49998  i've below json and i wanted to update few fie...
# 49999  i am using 15.0.1 version of firebase and goog...
#
#                                                     Tags
# 0             <linux><ubuntu><process><sandbox><selinux>
# 1                <java><graphics><jframe><jpanel><paint>
# 2      <security><ssh><ssh-keys><openssh><man-in-the-...
# 3       <c#><winforms><sqlite><datatable><sqlconnection>
# 4          <javascript><html><node.js><mongodb><express>
# ...                                                  ...
# 49995  <sql-server><ssas><oledb><sql-server-data-tool...
# 49996  <python><amazon-web-services><amazon-s3><boto3...
# 49997  <python><machine-learning><deep-learning><pyto...
# 49998         <java><json><rest><json-patch><http-patch>
# 49999  <android><android-studio><android-gradle-plugi...
#
# [50000 rows x 3 columns]

# %%
df['_clean_title']= df['Title'].parallel_apply(lambda x : final_clean(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df['_clean_body']= df['Body'].parallel_apply(lambda x : final_clean(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
def tags_cleaning(doc,
                   rejoin=False,
                 ) :
    """function of text processing"""

    #tokenizer
    tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+')
    raw_tokens_list = tokenizer.tokenize(doc)

    if rejoin:
        return " ".join(raw_tokens_list)

    return raw_tokens_list

# %%
def final_tag_clean(doc):
    new_doc = tags_cleaning(doc,
                           rejoin=True,
                           )
    return new_doc

# %%
df['_clean_tags']= df['Tags'].parallel_apply(lambda x : final_tag_clean(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df['_clean_tags_rejoin']= df['Tags'].parallel_apply(lambda x : final_tag_clean(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df.head(10)
# Out:
#                                                Title  \
# 0  giving a unix process exclusive rw access to a...
# 1           automatic repaint when minimizing window
# 2  is man-in-the-middle attack a security threat ...
# 3      managing data access in a simple winforms app
# 4                            render basic html view?
# 5  how to use nested-subfloders routing in nodejs...
# 6  using generics to process asp.net form request...
# 7  simple select(*) queries very slow in apache i...
# 8  ms sql server optimizer and varying table and ...
# 9                     how to wait for process child?
#
#                                                 Body  \
# 0  is there a way to sandbox a linux process into...
# 1  i have a jframe, with two panels, in one panel...
# 2  i am no expert in network security, so pardon ...
# 3  i have a simple winforms data entry app that u...
# 4  i have a basic node.js app that i am trying to...
# 5  i am working on a node project using express. ...
# 6  using jquery to post values back to an asp.net...
# 7  i'm prototyping apache ignite for use in a new...
# 8  we have a lot of queries for which we append a...
# 9  i do the usual fork + exec combination:\nint s...
#
#                                                 Tags  \
# 0         <linux><ubuntu><process><sandbox><selinux>
# 1            <java><graphics><jframe><jpanel><paint>
# 2  <security><ssh><ssh-keys><openssh><man-in-the-...
# 3   <c#><winforms><sqlite><datatable><sqlconnection>
# 4      <javascript><html><node.js><mongodb><express>
# 5  <node.js><express><routes><nested-routes><modu...
# 6      <c#><asp.net><generics><reflection><webforms>
# 7  <sql><performance><key-value><ignite><in-memor...
# 8  <sql><sql-server><sql-server-2005><tsql><query...
# 9                   <linux><posix><exec><fork><wait>
#
#                                         _clean_title  \
# 0  giving unix process exclusive rw access directory
# 1                automatic repaint minimizing window
# 2  man-in-the-middle attack security threat ssh a...
# 3           managing data access simple winforms app
# 4                             render basic html view
# 5  use nested-subfloders routing nodejs express a...
# 6  using generic process asp.net form request var...
# 7             simple select query slow apache ignite
# 8   m sql server optimizer varying table field alias
# 9                                 wait process child
#
#                                          _clean_body  \
# 0  way sandbox linux process certain directory gi...
# 1  jframe two panel one panel draw line working m...
# 2  expert network security pardon question smart ...
# 3  simple winforms data entry app us sqlite alway...
# 4  basic node.js app trying get ground using expr...
# 5  working node project using express folder rout...
# 6  using jquery post value back asp.net webform c...
# 7  prototyping apache ignite use new product need...
# 8  lot query append random alias end field table ...
# 9  usual fork + exec combination int socket socke...
#
#                                          _clean_tags  \
# 0         [linux, ubuntu, process, sandbox, selinux]
# 1            [java, graphics, jframe, jpanel, paint]
# 2  [security, ssh, ssh-keys, openssh, man-in-the-...
# 3   [c#, winforms, sqlite, datatable, sqlconnection]
# 4      [javascript, html, node.js, mongodb, express]
# 5  [node.js, express, routes, nested-routes, modu...
# 6      [c#, asp.net, generics, reflection, webforms]
# 7  [sql, performance, key-value, ignite, in-memor...
# 8  [sql, sql-server, sql-server, tsql, query-opti...
# 9                   [linux, posix, exec, fork, wait]
#
#                                   _clean_tags_rejoin
# 0               linux ubuntu process sandbox selinux
# 1                  java graphics jframe jpanel paint
# 2    security ssh ssh-keys openssh man-in-the-middle
# 3         c# winforms sqlite datatable sqlconnection
# 4            javascript html node.js mongodb express
# 5  node.js express routes nested-routes module-ex...
# 6            c# asp.net generics reflection webforms
# 7  sql performance key-value ignite in-memory-dat...
# 8  sql sql-server sql-server tsql query-optimization
# 9                         linux posix exec fork wait

# %%
df['Title'] = df['_clean_title']

# %%
df['Body'] = df['_clean_body']

# %%
df['Tags'] = df['_clean_tags_rejoin']

# %%
tmp = df.Body.str.len()

# %%
df["_len_body"] = tmp
df.head(10)
# Out:
#                                                Title  \
# 0  giving unix process exclusive rw access directory
# 1                automatic repaint minimizing window
# 2  man-in-the-middle attack security threat ssh a...
# 3           managing data access simple winforms app
# 4                             render basic html view
# 5  use nested-subfloders routing nodejs express a...
# 6  using generic process asp.net form request var...
# 7             simple select query slow apache ignite
# 8   m sql server optimizer varying table field alias
# 9                                 wait process child
#
#                                                 Body  \
# 0  way sandbox linux process certain directory gi...
# 1  jframe two panel one panel draw line working m...
# 2  expert network security pardon question smart ...
# 3  simple winforms data entry app us sqlite alway...
# 4  basic node.js app trying get ground using expr...
# 5  working node project using express folder rout...
# 6  using jquery post value back asp.net webform c...
# 7  prototyping apache ignite use new product need...
# 8  lot query append random alias end field table ...
# 9  usual fork + exec combination int socket socke...
#
#                                                 Tags  \
# 0               linux ubuntu process sandbox selinux
# 1                  java graphics jframe jpanel paint
# 2    security ssh ssh-keys openssh man-in-the-middle
# 3         c# winforms sqlite datatable sqlconnection
# 4            javascript html node.js mongodb express
# 5  node.js express routes nested-routes module-ex...
# 6            c# asp.net generics reflection webforms
# 7  sql performance key-value ignite in-memory-dat...
# 8  sql sql-server sql-server tsql query-optimization
# 9                         linux posix exec fork wait
#
#                                         _clean_title  \
# 0  giving unix process exclusive rw access directory
# 1                automatic repaint minimizing window
# 2  man-in-the-middle attack security threat ssh a...
# 3           managing data access simple winforms app
# 4                             render basic html view
# 5  use nested-subfloders routing nodejs express a...
# 6  using generic process asp.net form request var...
# 7             simple select query slow apache ignite
# 8   m sql server optimizer varying table field alias
# 9                                 wait process child
#
#                                          _clean_body  \
# 0  way sandbox linux process certain directory gi...
# 1  jframe two panel one panel draw line working m...
# 2  expert network security pardon question smart ...
# 3  simple winforms data entry app us sqlite alway...
# 4  basic node.js app trying get ground using expr...
# 5  working node project using express folder rout...
# 6  using jquery post value back asp.net webform c...
# 7  prototyping apache ignite use new product need...
# 8  lot query append random alias end field table ...
# 9  usual fork + exec combination int socket socke...
#
#                                          _clean_tags  \
# 0         [linux, ubuntu, process, sandbox, selinux]
# 1            [java, graphics, jframe, jpanel, paint]
# 2  [security, ssh, ssh-keys, openssh, man-in-the-...
# 3   [c#, winforms, sqlite, datatable, sqlconnection]
# 4      [javascript, html, node.js, mongodb, express]
# 5  [node.js, express, routes, nested-routes, modu...
# 6      [c#, asp.net, generics, reflection, webforms]
# 7  [sql, performance, key-value, ignite, in-memor...
# 8  [sql, sql-server, sql-server, tsql, query-opti...
# 9                   [linux, posix, exec, fork, wait]
#
#                                   _clean_tags_rejoin  _len_body
# 0               linux ubuntu process sandbox selinux        526
# 1                  java graphics jframe jpanel paint       2969
# 2    security ssh ssh-keys openssh man-in-the-middle        447
# 3         c# winforms sqlite datatable sqlconnection       2537
# 4            javascript html node.js mongodb express        335
# 5  node.js express routes nested-routes module-ex...        674
# 6            c# asp.net generics reflection webforms        705
# 7  sql performance key-value ignite in-memory-dat...       1006
# 8  sql sql-server sql-server tsql query-optimization        363
# 9                         linux posix exec fork wait        265

# %%
df = df.drop(['_clean_title','_clean_body','_clean_tags_rejoin'], axis=1)

# %%
df
# Out:
#                                                    Title  \
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3               managing data access simple winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation currently pr...
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .internal .resolve .artifactnotfoun...
#
#                                                     Body  \
# 0      way sandbox linux process certain directory gi...
# 1      jframe two panel one panel draw line working m...
# 2      expert network security pardon question smart ...
# 3      simple winforms data entry app us sqlite alway...
# 4      basic node.js app trying get ground using expr...
# ...                                                  ...
# 49995  using ssis tool ole db downloading data vertic...
# 49996  using f uploading file already created bucket ...
# 49997  following jupyter notebook course hit upon err...
# 49998  json wanted update field process my-process po...
# 49999  using version firebase google play service bui...
#
#                                                     Tags  \
# 0                   linux ubuntu process sandbox selinux
# 1                      java graphics jframe jpanel paint
# 2        security ssh ssh-keys openssh man-in-the-middle
# 3             c# winforms sqlite datatable sqlconnection
# 4                javascript html node.js mongodb express
# ...                                                  ...
# 49995  sql-server ssas oledb sql-server-data-tools ve...
# 49996  python amazon-web-services amazon-s boto pytho...
# 49997  python machine-learning deep-learning pytorch ...
# 49998               java json rest json-patch http-patch
# 49999  android android-studio android-gradle-plugin g...
#
#                                              _clean_tags  _len_body
# 0             [linux, ubuntu, process, sandbox, selinux]        526
# 1                [java, graphics, jframe, jpanel, paint]       2969
# 2      [security, ssh, ssh-keys, openssh, man-in-the-...        447
# 3       [c#, winforms, sqlite, datatable, sqlconnection]       2537
# 4          [javascript, html, node.js, mongodb, express]        335
# ...                                                  ...        ...
# 49995  [sql-server, ssas, oledb, sql-server-data-tool...        206
# 49996  [python, amazon-web-services, amazon-s, boto, ...        301
# 49997  [python, machine-learning, deep-learning, pyto...        908
# 49998         [java, json, rest, json-patch, http-patch]        645
# 49999  [android, android-studio, android-gradle-plugi...      27209
#
# [50000 rows x 5 columns]

# %%
df.to_csv("data/cleaned/df_process_text.csv", index=False)

# %%
raw_corpus_text = " ".join(df.Body.values)
raw_corpus_text[:1000]
# Out:
# 'way sandbox linux process certain directory give process exclusive rw access dir example create temporary working directory start e.g python another scripting tool way write directory without limiting much functionality also process access read directory except superusers course need sandbox web service basically allows user run arbitrary code currently authorization software end process run one linux user would need way user cannot harm system temporary private working directory write read file protected user webservice jframe two panel one panel draw line working minimized window java program maximized line drew different repainted different place anyone idea lock painting minimize screw drawing thank import java.awt import javax.swing import java.awt .event import java.io import java.util import javax.imageio .imageio import java.awt .graphics import java.awt .image .bufferedimage import java.io .file class jframepaint extends jframe implement actionlistener implement actionlistener'

# %%
raw_corpus_tags = " ".join(df.Tags.values)
raw_corpus_tags[:1000]
# Out:
# 'linux ubuntu process sandbox selinux java graphics jframe jpanel paint security ssh ssh-keys openssh man-in-the-middle c# winforms sqlite datatable sqlconnection javascript html node.js mongodb express node.js express routes nested-routes module-export c# asp.net generics reflection webforms sql performance key-value ignite in-memory-database sql sql-server sql-server tsql query-optimization linux posix exec fork wait c# .net ienumerable overloading ilist .net configuration import export configuration-files memory linker embedded loader firmware ios regex swift string emoji http angular typescript request http-post sql function postgresql plpgsql dynamic-sql python mysql database django amazon-ec .net wcf web-services certificate wshttpbinding ruby-on-rails ruby activerecord scriptaculous jquery-ui-sortable css wordpress sass wordpress-theming zurb-foundation sorting reporting-services ssrs interactive subreport visual-studio xaml silverlight c# tabcontrol java exception-handling java.'

# %%
tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+')
raw_tokens_tags= tokenizer.tokenize(raw_corpus_tags)
raw_tokens_text = tokenizer.tokenize(raw_corpus_text)

# %%
display_tokens_info(raw_tokens_tags)
# Out:
# nb tokens 254932, nb tokens uniques 18044
# ['linux', 'ubuntu', 'process', 'sandbox', 'selinux', 'java', 'graphics', 'jframe', 'jpanel', 'paint', 'security', 'ssh', 'ssh-keys', 'openssh', 'man-in-the-middle', 'c#', 'winforms', 'sqlite', 'datatable', 'sqlconnection', 'javascript', 'html', 'node.js', 'mongodb', 'express', 'node.js', 'express', 'routes', 'nested-routes', 'module-export']

# %%
bad_word = ['using']
raw_tokens_tags = [word for word in raw_tokens_tags if word not in bad_word]

# %%
display_tokens_info(raw_tokens_text)
# Out:
# nb tokens 6999158, nb tokens uniques 468801
# ['way', 'sandbox', 'linux', 'process', 'certain', 'directory', 'give', 'process', 'exclusive', 'rw', 'access', 'dir', 'example', 'create', 'temporary', 'working', 'directory', 'start', 'e.g', 'python', 'another', 'scripting', 'tool', 'way', 'write', 'directory', 'without', 'limiting', 'much', 'functionality']

# %%
tmp_tags = pd.Series(raw_tokens_tags).value_counts()
len(tmp_tags)
# Out:
# 18043

# %%
tmp_tags[:2000]
# Out:
# c#                    6699
# java                  6278
# javascript            6236
# python                5638
# asp.net               4193
#                       ...
# d-iphone                15
# tokenize                15
# contenteditable         15
# naming-conventions      15
# scheduler               15
# Length: 2000, dtype: int64

# %%
tmp_tags[tmp_tags > 100]
# Out:
# c#                        6699
# java                      6278
# javascript                6236
# python                    5638
# asp.net                   4193
#                           ...
# character-encoding         101
# multidimensional-array     101
# google-cloud-platform      101
# upload                     101
# outlook                    101
# Length: 348, dtype: int64

# %%
list_tags_words_most_used = list(tmp_tags[tmp_tags > 100].index)
len(list_tags_words_most_used)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [183], in <cell line: 1>()
# ----> 1 list_tags_words_most_used = list(tmp_tags[tmp_tags > 100].index)
#       2 len(list_tags_words_most_used)
#
# TypeError: 'list' object is not callable

# %%
list_tags_words = list(tmp_tags.index)
len(list_tags_words)
# Out:
# 18043

# %%
list_tags_words
# Out:
# ['c#',
#  'java',
#  'javascript',
#  'python',
#  'asp.net',
#  'php',
#  'html',
#  '.net',
#  'jquery',
#  'c++',
#  'android',
#  'ios',
#  'css',
#  'sql',
#  'sql-server',
#  'mysql',
#  'node.js',
#  'visual-studio',
#  '-mvc',
#  'c',
#  'objective-c',
#  'json',
#  'ruby-on-rails',
#  'iphone',
#  'windows',
#  'spring',
#  'linux',
#  'ajax',
#  'swift',
#  'arrays',
#  'wpf',
#  'angular',
#  '.x',
#  'xml',
#  'laravel',
#  'database',
#  'reactjs',
#  'xcode',
#  'django',
#  'ruby',
#  'multithreading',
#  'string',
#  'performance',
#  'spring-boot',
#  'angularjs',
#  'image',
#  '-core',
#  'macos',
#  'unit-testing',
#  'typescript',
#  'rest',
#  'twitter-bootstrap',
#  'vb.net',
#  'hibernate',
#  'amazon-web-services',
#  'oracle',
#  'apache',
#  'winforms',
#  'pandas',
#  'web-services',
#  'maven',
#  'excel',
#  'forms',
#  'eclipse',
#  'r',
#  'postgresql',
#  'd',
#  'wordpress',
#  'api',
#  'algorithm',
#  'xaml',
#  'bash',
#  'entity-framework',
#  'internet-explorer',
#  'qt',
#  'security',
#  'regex',
#  'firebase',
#  'selenium',
#  'http',
#  'authentication',
#  'ubuntu',
#  'azure',
#  'swing',
#  'file',
#  'iis',
#  'docker',
#  'linq',
#  'list',
#  'mongodb',
#  'tomcat',
#  'user-interface',
#  'jpa',
#  'shell',
#  'sockets',
#  'express',
#  'validation',
#  'google-chrome',
#  'spring-mvc',
#  'parsing',
#  'dataframe',
#  'function',
#  'wcf',
#  'numpy',
#  'csv',
#  'ssl',
#  'cocoa-touch',
#  'x',
#  'android-studio',
#  'machine-learning',
#  'actionscript',
#  'opencv',
#  'gcc',
#  'class',
#  'symfony',
#  'datetime',
#  'asynchronous',
#  'git',
#  'unix',
#  'jsp',
#  'loops',
#  'email',
#  'debugging',
#  'tensorflow',
#  'cocoa',
#  'vue.js',
#  'testing',
#  'winapi',
#  'exception',
#  'sqlite',
#  'apache-spark',
#  'events',
#  'react-native',
#  'object',
#  'tsql',
#  'selenium-webdriver',
#  '-web-api',
#  'scala',
#  'flash',
#  'date',
#  'post',
#  'amazon-s',
#  'networking',
#  'pdf',
#  'optimization',
#  'sorting',
#  'delphi',
#  'image-processing',
#  'firefox',
#  'video',
#  'assembly',
#  'encryption',
#  'data-binding',
#  'vba',
#  'oauth',
#  'silverlight',
#  'jakarta-ee',
#  'cordova',
#  'xamarin',
#  'session',
#  'mvvm',
#  'url',
#  'uitableview',
#  'junit',
#  'serialization',
#  'templates',
#  'google-maps',
#  'variables',
#  'keras',
#  'memory',
#  'dll',
#  'kotlin',
#  'listview',
#  'web',
#  'sharepoint',
#  'oop',
#  'caching',
#  '.htaccess',
#  'matplotlib',
#  'jdbc',
#  'math',
#  'apache-flex',
#  'utf',
#  'soap',
#  'dictionary',
#  'pyqt',
#  'generics',
#  'dom',
#  'button',
#  'visual-c++',
#  'search',
#  'memory-management',
#  'gradle',
#  'facebook',
#  'flask',
#  'windows-phone',
#  'encoding',
#  'npm',
#  'animation',
#  'unicode',
#  'flutter',
#  'orm',
#  'stored-procedures',
#  'hadoop',
#  'audio',
#  'deployment',
#  'pointers',
#  'opengl',
#  'curl',
#  'logging',
#  'nginx',
#  'installation',
#  'jquery-ui',
#  'woocommerce',
#  'webpack',
#  'text',
#  'inheritance',
#  'matlab',
#  'servlets',
#  'android-layout',
#  'ionic-framework',
#  'canvas',
#  'jsf',
#  'tcp',
#  'cookies',
#  'jenkins',
#  'gridview',
#  'dynamic',
#  'codeigniter',
#  'for-loop',
#  'android-fragments',
#  'graphics',
#  'perl',
#  'browser',
#  'powershell',
#  'spring-security',
#  'ipad',
#  'ms-access',
#  'xpath',
#  'https',
#  'redirect',
#  'design-patterns',
#  'build',
#  'input',
#  'razor',
#  'data-structures',
#  'web-applications',
#  'select',
#  'file-upload',
#  'kubernetes',
#  'heroku',
#  'iframe',
#  'amazon-ec',
#  'lambda',
#  'command-line',
#  'model-view-controller',
#  'j',
#  'boost',
#  'struts',
#  'filter',
#  'concurrency',
#  'matrix',
#  'ssh',
#  'pyspark',
#  'com',
#  'plugins',
#  'datatable',
#  'mocking',
#  'dependency-injection',
#  'ionic',
#  'svg',
#  'vector',
#  'redux',
#  'plot',
#  'linq-to-sql',
#  'intellij-idea',
#  'import',
#  'configuration',
#  'uiview',
#  'jboss',
#  'deep-learning',
#  'web-scraping',
#  'memory-leaks',
#  'database-design',
#  'batch-file',
#  'checkbox',
#  'binding',
#  'javafx',
#  'netbeans',
#  'async-await',
#  'scikit-learn',
#  'types',
#  'dart',
#  'unity',
#  'mod-rewrite',
#  'xamarin.forms',
#  'parameters',
#  '-bit',
#  'collections',
#  'reflection',
#  'transactions',
#  'spring-data-jpa',
#  'google-app-engine',
#  'terminal',
#  'aws-lambda',
#  'datagrid',
#  'core-data',
#  'websocket',
#  'nhibernate',
#  'drop-down-menu',
#  'ecmascript',
#  'methods',
#  'indexing',
#  'django-models',
#  'graph',
#  'jackson',
#  'colors',
#  'mongoose',
#  'linker',
#  'recursion',
#  'layout',
#  'fonts',
#  'cakephp',
#  'hash',
#  'join',
#  'safari',
#  'ffmpeg',
#  'scroll',
#  'http-status-code',
#  'automation',
#  'docker-compose',
#  'mobile',
#  'time',
#  'path',
#  'charts',
#  'error-handling',
#  'file-io',
#  'proxy',
#  'github',
#  'g',
#  'struct',
#  'certificate',
#  'process',
#  'character-encoding',
#  'multidimensional-array',
#  'google-cloud-platform',
#  'upload',
#  'outlook',
#  'listbox',
#  'permissions',
#  'if-statement',
#  'properties',
#  'scipy',
#  'download',
#  'ado.net',
#  'continuous-integration',
#  'scripting',
#  'replace',
#  'random',
#  'parallel-processing',
#  'service',
#  'jar',
#  'drupal',
#  'magento',
#  'arraylist',
#  'vuejs',
#  'svn',
#  'neural-network',
#  'stl',
#  'zend-framework',
#  'interop',
#  'stream',
#  'pip',
#  'bootstrap',
#  'static',
#  'uiviewcontroller',
#  'directory',
#  'azure-devops',
#  'uikit',
#  'uwp',
#  'combobox',
#  'google-api',
#  'ejb',
#  'firebase-realtime-database',
#  'log',
#  'cmd',
#  'request',
#  'yii',
#  'activerecord',
#  'xslt',
#  'playframework',
#  'axios',
#  'automated-tests',
#  'module',
#  'interface',
#  'computer-vision',
#  'uinavigationcontroller',
#  '.js',
#  'controller',
#  'ssis',
#  'extjs',
#  'promise',
#  'android-intent',
#  'null',
#  'callback',
#  'centos',
#  'xamarin.android',
#  'printing',
#  'architecture',
#  'dependencies',
#  'doctrine-orm',
#  'enums',
#  'wsdl',
#  'datagridview',
#  'autocomplete',
#  'internationalization',
#  'compilation',
#  'hive',
#  'bluetooth',
#  'push-notification',
#  'tree',
#  'constructor',
#  'jestjs',
#  'embedded',
#  'cryptography',
#  'eloquent',
#  'retrofit',
#  'server',
#  'version-control',
#  'google-cloud-firestore',
#  'tkinter',
#  'bitmap',
#  'openssl',
#  'visual-studio-code',
#  'hyperlink',
#  'responsive-design',
#  'linux-kernel',
#  'jwt',
#  'event-handling',
#  'controls',
#  'insert',
#  'datepicker',
#  'apache-spark-sql',
#  'go',
#  'user-controls',
#  'elasticsearch',
#  'raspberry-pi',
#  'compiler-construction',
#  'url-rewriting',
#  'floating-point',
#  'sass',
#  'makefile',
#  'localization',
#  'jersey',
#  'base',
#  'mono',
#  'view',
#  'mockito',
#  'streaming',
#  'selenium-chromedriver',
#  'nlp',
#  'onclick',
#  'msbuild',
#  'timer',
#  'ms-word',
#  'crash',
#  'apache-kafka',
#  'group-by',
#  'sed',
#  'webview',
#  'model',
#  'mfc',
#  'active-directory',
#  'udp',
#  'casting',
#  'react-redux',
#  'reference',
#  'android-activity',
#  'merge',
#  'jupyter-notebook',
#  'xamarin.ios',
#  'xsd',
#  'google-maps-api',
#  'awk',
#  'get',
#  'background',
#  'exception-handling',
#  'weblogic',
#  'google-sheets',
#  'spring-data',
#  'split',
#  'kendo-ui',
#  'android-ndk',
#  'annotations',
#  'android-gradle-plugin',
#  'django-rest-framework',
#  'delegates',
#  'passwords',
#  'windows-server',
#  'entity-framework-core',
#  'frameworks',
#  'angular-material',
#  'foreach',
#  'html-table',
#  'dockerfile',
#  'header',
#  'webdriver',
#  'modal-dialog',
#  'http-headers',
#  'binary',
#  'language-agnostic',
#  'formatting',
#  'smtp',
#  'resources',
#  'android-recyclerview',
#  'cmake',
#  'twitter',
#  'plsql',
#  'joomla',
#  'azure-active-directory',
#  'firebase-authentication',
#  'connection',
#  'geometry',
#  'youtube',
#  'ant',
#  'jquery-mobile',
#  'count',
#  'io',
#  'grid',
#  'uicollectionview',
#  'arm',
#  'cross-platform',
#  'g++',
#  'compression',
#  'rxjs',
#  'triggers',
#  'dataset',
#  'cross-browser',
#  'pagination',
#  'windows-services',
#  'google-chrome-extension',
#  'gwt',
#  'keyboard',
#  'uiwebview',
#  'cron',
#  'reporting-services',
#  'rotation',
#  'textbox',
#  'menu',
#  'jasmine',
#  'rubygems',
#  'groovy',
#  'resize',
#  'xmlhttprequest',
#  'operating-system',
#  'namespaces',
#  'cors',
#  'locking',
#  'migration',
#  'vb',
#  'widget',
#  'rspec',
#  'react-hooks',
#  'routes',
#  'redis',
#  'dialog',
#  'popup',
#  'python-requests',
#  'nunit',
#  'sdk',
#  'datatables',
#  'attributes',
#  'jaxb',
#  'dns',
#  'facebook-graph-api',
#  'console',
#  'swagger',
#  'xhtml',
#  'webforms',
#  'nested',
#  '-identity',
#  'schema',
#  'jvm',
#  'routing',
#  'compiler-errors',
#  'initialization',
#  'jquery-plugins',
#  'treeview',
#  'uiimageview',
#  'firebase-cloud-messaging',
#  'socket.io',
#  'opengl-es',
#  'zip',
#  'authorization',
#  'format',
#  'timeout',
#  'tdd',
#  'web-config',
#  'conv-neural-network',
#  'jpanel',
#  '-core-mvc',
#  'save',
#  'doctrine',
#  'e',
#  'glassfish',
#  'telerik',
#  'java-native-interface',
#  'filesystems',
#  'synchronization',
#  'export',
#  'django-views',
#  'iterator',
#  'command',
#  'thread-safety',
#  'ide',
#  'garbage-collection',
#  'jax-rs',
#  'tfs',
#  'coldfusion',
#  'gdb',
#  'type-conversion',
#  'focus',
#  'ldap',
#  'uiscrollview',
#  'blob',
#  'ssl-certificate',
#  'anaconda',
#  'window',
#  'tabs',
#  'mocha.js',
#  'sqlalchemy',
#  'arduino',
#  'dom-events',
#  'scope',
#  'jframe',
#  'beautifulsoup',
#  'cassandra',
#  'storyboard',
#  'camera',
#  'png',
#  'queue',
#  'cucumber',
#  'posix',
#  'time-series',
#  'timestamp',
#  'grails',
#  'vbscript',
#  'haskell',
#  'int',
#  'click',
#  'navigation',
#  'while-loop',
#  'usb',
#  'slider',
#  'network-programming',
#  'syntax',
#  'mingw',
#  'foreign-keys',
#  'ftp',
#  'many-to-many',
#  'clang',
#  'functional-programming',
#  'bit',
#  'escaping',
#  'jtable',
#  'gtk',
#  'django-forms',
#  'package',
#  'pipe',
#  'comparison',
#  'google-cloud-functions',
#  'windows-mobile',
#  'ggplot',
#  '-r',
#  'find',
#  'directx',
#  'django-templates',
#  'map',
#  'drag-and-drop',
#  'shared-libraries',
#  'calendar',
#  'components',
#  'pdf-generation',
#  'css-selectors',
#  'persistence',
#  'containers',
#  'editor',
#  'arguments',
#  'hashmap',
#  'odbc',
#  'icons',
#  'moq',
#  'pinvoke',
#  'clr',
#  'statistics',
#  'angularjs-directive',
#  'environment-variables',
#  'aes',
#  'localhost',
#  'char',
#  'rsa',
#  'windows-vista',
#  'overriding',
#  'gmail',
#  'graphql',
#  'websphere',
#  'multiprocessing',
#  'mapping',
#  'swiftui',
#  'marshalling',
#  'devise',
#  'constants',
#  'single-sign-on',
#  'stack',
#  'pdo',
#  'video-streaming',
#  'solr',
#  'windows-store-apps',
#  'label',
#  'boto',
#  'geolocation',
#  'mp',
#  'uibutton',
#  'h',
#  'dynamics-crm',
#  'uitextview',
#  'google-apps-script',
#  'repository',
#  'kernel',
#  '-ajax',
#  'build-process',
#  'odoo',
#  'frontend',
#  'serial-port',
#  'integer',
#  'styles',
#  'google-oauth',
#  'notifications',
#  'osgi',
#  'stdout',
#  'nosql',
#  'bootstrap-modal',
#  'xml-parsing',
#  'segmentation-fault',
#  'gps',
#  'amazon-dynamodb',
#  'vue-component',
#  'gzip',
#  'character',
#  'timezone',
#  'tags',
#  'datasource',
#  'json.net',
#  'fetch',
#  'microservices',
#  'debian',
#  'autolayout',
#  'rx-java',
#  'nullpointerexception',
#  'uiimage',
#  'primary-key',
#  'sum',
#  'android-viewpager',
#  'textview',
#  'hover',
#  'product',
#  'react-router',
#  'activex',
#  'next.js',
#  'virtual-machine',
#  'xampp',
#  'mapreduce',
#  'rendering',
#  'shiny',
#  'buffer',
#  'scrapy',
#  'bluetooth-lowenergy',
#  'integration-testing',
#  'build.gradle',
#  'java-me',
#  'cuda',
#  'yaml',
#  'etl',
#  'exe',
#  'cocoapods',
#  'apple-push-notifications',
#  'range',
#  'e-testing',
#  'babeljs',
#  'coordinates',
#  'gitlab',
#  'eclipse-plugin',
#  'jms',
#  'linq-to-entities',
#  'seaborn',
#  'constraints',
#  'flex',
#  'windows-runtime',
#  'windows-xp',
#  'progress-bar',
#  'fluent-nhibernate',
#  'assemblies',
#  'nuget',
#  'copy',
#  'include',
#  'sprite-kit',
#  'database-connection',
#  'google-analytics',
#  'gulp',
#  'compact-framework',
#  'android-listview',
#  'key',
#  'sql-update',
#  'air',
#  'out-of-memory',
#  'ascii',
#  'es',
#  '-canvas',
#  'lucene',
#  'report',
#  'cloud',
#  'radio-button',
#  'oledb',
#  'webrtc',
#  'jenkins-pipeline',
#  'azure-pipelines',
#  'asmx',
#  'client',
#  'nsstring',
#  'macros',
#  'lua',
#  'boolean',
#  'position',
#  'lazy-loading',
#  'jmeter',
#  'primefaces',
#  'fork',
#  'material-ui',
#  'db',
#  'typo',
#  'gis',
#  'windows-installer',
#  'runtime',
#  'compare',
#  'numbers',
#  'backbone.js',
#  'material-design',
#  'pycharm',
#  'sha',
#  'wix',
#  'android-asynctask',
#  'accessibility',
#  'pytorch',
#  'thymeleaf',
#  'virtualenv',
#  'ipc',
#  'mouse',
#  'emacs',
#  'rabbitmq',
#  'google-play',
#  'karma-jasmine',
#  'set',
#  'azure-web-app-service',
#  'office',
#  'alignment',
#  'subprocess',
#  'time-complexity',
#  'appium',
#  'ms-office',
#  'iteration',
#  'sublimetext',
#  'try-catch',
#  'uinavigationbar',
#  'native',
#  'polymorphism',
#  'webkit',
#  'pthreads',
#  'size',
#  'response',
#  'testcafe',
#  'google-sheets-formula',
#  'data-science',
#  'token',
#  'aws-sdk',
#  'coding-style',
#  'hex',
#  'interface-builder',
#  'artificial-intelligence',
#  'global-variables',
#  'electron',
#  'inversion-of-control',
#  'meteor',
#  'webserver',
#  'protractor',
#  'observable',
#  'http-post',
#  'metadata',
#  'exchange-server',
#  'custom-controls',
#  'full-text-search',
#  'cross-compiling',
#  'phpunit',
#  'hdfs',
#  'client-server',
#  'transform',
#  'latex',
#  'azure-functions',
#  'bigdata',
#  'jpeg',
#  'httprequest',
#  'rss',
#  'signals',
#  'core-graphics',
#  'web-crawler',
#  'decimal',
#  'google-cloud-messaging',
#  'cross-domain',
#  'celery',
#  'ef-code-first',
#  'bots',
#  'imageview',
#  'bit-manipulation',
#  'sonarqube',
#  'httpwebrequest',
#  'postman',
#  'vagrant',
#  'lstm',
#  'cygwin',
#  'location',
#  'axis',
#  'load',
#  'command-line-interface',
#  'registry',
#  'afnetworking',
#  'google-drive-api',
#  'devops',
#  'owin',
#  'domain-driven-design',
#  'jetty',
#  'classification',
#  'leaflet',
#  'field',
#  'maps',
#  'overlay',
#  'task',
#  'forms-authentication',
#  'singleton',
#  'vim',
#  'global',
#  'google-maps-markers',
#  'driver',
#  'itext',
#  'textures',
#  'return',
#  'themes',
#  'screen-scraping',
#  'repository-pattern',
#  'single-page-application',
#  'deserialization',
#  'updatepanel',
#  'tuples',
#  'apk',
#  'imagemagick',
#  'httpclient',
#  'gdi+',
#  'core-animation',
#  'port',
#  'android-edittext',
#  'width',
#  'azure-blob-storage',
#  'karma-runner',
#  'angularjs-scope',
#  'vsto',
#  'in-app-purchase',
#  'submit',
#  'mysqli',
#  'overflow',
#  'byte',
#  'settings',
#  'osx-mavericks',
#  'overloading',
#  'python-imaging-library',
#  'listener',
#  'visualization',
#  'asp-classic',
#  'gpu',
#  'height',
#  'flask-sqlalchemy',
#  'linked-list',
#  'linker-errors',
#  'signalr',
#  'textarea',
#  'expo',
#  'nltk',
#  'scrollbar',
#  'highcharts',
#  'jupyter',
#  'devexpress',
#  'regression',
#  'xml-serialization',
#  ...]

# %%
raw_tokens_tags[:10]
# Out:
# ['linux',
#  'ubuntu',
#  'process',
#  'sandbox',
#  'selinux',
#  'java',
#  'graphics',
#  'jframe',
#  'jpanel',
#  'paint']

# %%
raw_tokens_tags.va

# %% [markdown]
# #### --- saving the tags words ---

# %%
list_tags_words_df = pd.DataFrame({"words" : list_tags_words})
list_tags_words_df.to_csv("data/cleaned/tag_words.csv", index=False)
list_tags_words_df
# Out:
#                 words
# 0                  c#
# 1                java
# 2          javascript
# 3              python
# 4             asp.net
# ...               ...
# 18038       cloudbees
# 18039        djcelery
# 18040    copywithzone
# 18041  time-precision
# 18042      http-patch
#
# [18043 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
wordcloud = WordCloud(background_color='white',
                      stopwords=[],
                      max_words=50).generate(" ".join(raw_tokens_text))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
wordcloud = WordCloud(background_color='white',
                      stopwords=[],
                      max_words=50).generate(" ".join(raw_tokens_tags))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
tmp_text= pd.Series(raw_tokens_text).value_counts()
tmp_text[tmp_text > 50]
# Out:
# class         43146
# new           40188
# file          38885
# using         36668
# string        34498
#               ...
# smartphone       51
# .closest         51
# vals             51
# jks              51
# ne               51
# Length: 9087, dtype: int64

# %%
list_most_freq_words = list((tmp_text[tmp_text > 50]).index)
len(list_most_freq_words)
# Out:
# 9087

# %%
list_most_freq_words[:60]
# Out:
# ['class',
#  'new',
#  'file',
#  'using',
#  'string',
#  'name',
#  'code',
#  'error',
#  'public',
#  '+',
#  'get',
#  'return',
#  'x',
#  'data',
#  'function',
#  'id',
#  'value',
#  'http',
#  'user',
#  'like',
#  'c',
#  'use',
#  'div',
#  'type',
#  'work',
#  'var',
#  '#',
#  'int',
#  'true',
#  'import',
#  'want',
#  'e',
#  'would',
#  'set',
#  'android',
#  'b',
#  'object',
#  'app',
#  'one',
#  'method',
#  'application',
#  'server',
#  'void',
#  'null',
#  'need',
#  'problem',
#  'text',
#  'image',
#  'way',
#  'test',
#  'version',
#  'f',
#  'trying',
#  'table',
#  'n',
#  'private',
#  'script',
#  'line',
#  'list',
#  'false']

# %%
elems_not_to_drop_high_freq = set(list_most_freq_words) & set(list_tags_words)
len(elems_not_to_drop_high_freq)
# Out:
# 2828

# %%
elems_not_to_drop_high_freq
# Out:
# {'suspend',
#  'argv',
#  'tensorboard',
#  'synchronous',
#  'xamarin.forms',
#  'xmlhttprequest',
#  'pow',
#  'zip',
#  'pca',
#  'fill',
#  'friend',
#  'xmlwriter',
#  'hdfs',
#  'report',
#  'observable',
#  'session',
#  'imagedata',
#  'flat',
#  'graphql',
#  'keycode',
#  'playback',
#  'navbar',
#  'nsdate',
#  'combobox',
#  'blueprint',
#  'lambda',
#  'chai',
#  'httpcontext',
#  'redirect',
#  'yaml',
#  'bluetooth',
#  'clause',
#  'rack',
#  'body-parser',
#  'block',
#  'nm',
#  'evaluation',
#  'dropbox',
#  'lookup',
#  'forum',
#  'protection',
#  'reader',
#  'osc',
#  'permutation',
#  'storage',
#  'transient',
#  'refer',
#  'gemfile',
#  'iostream',
#  'iboutlet',
#  'taglib',
#  'keyup',
#  'built-in',
#  'z-index',
#  'jta',
#  'dart',
#  'pad',
#  'code',
#  'mov',
#  'support-v',
#  'keyvaluepair',
#  '.datatable',
#  'geometry',
#  'uniform',
#  'cpu',
#  'moq',
#  'uiapplication',
#  'sam',
#  'wsse',
#  'region',
#  'pack',
#  'dimension',
#  'system.data',
#  'cassandra',
#  'applet',
#  'ip',
#  'logstash',
#  'ghc',
#  'recording',
#  'psycopg',
#  'tcpclient',
#  'hyperlink',
#  'uinavigationcontroller',
#  'required',
#  'sqlcommand',
#  'interceptor',
#  'get',
#  'lodash',
#  'plot',
#  'module',
#  'indexed',
#  'alt',
#  'elevation',
#  'throwable',
#  'nsfetchedresultscontroller',
#  'review',
#  'controltemplate',
#  'meta',
#  'glib',
#  'appdata',
#  'collect',
#  'head',
#  'nserror',
#  'ipad',
#  'richtextbox',
#  'scanf',
#  'printf',
#  'dateadd',
#  'positioning',
#  'mmap',
#  'struct',
#  'minimize',
#  'sidebar',
#  'modelattribute',
#  'put',
#  'cp',
#  'textfield',
#  'phpmailer',
#  'analysis',
#  'shader',
#  'combine',
#  'tfs',
#  'csv',
#  'ear',
#  'geolocation',
#  'scaling',
#  'alignment',
#  'csrf',
#  'xpath',
#  'encryption',
#  'vue.js',
#  'mocking',
#  'touch',
#  'mex',
#  'find',
#  '.concurrent',
#  'urlrequest',
#  'imagemagick',
#  'intel',
#  'application.properties',
#  'relaycommand',
#  'state',
#  'gravity',
#  'numpy',
#  'oftype',
#  'alarm',
#  'avx',
#  '.post',
#  'fancybox',
#  'swagger',
#  'multiprocessing',
#  'sudo',
#  'typeof',
#  'sqldataadapter',
#  'terraform',
#  'xmldocument',
#  'inputstreamreader',
#  'keystore',
#  'uitableview',
#  'uicollectionview',
#  'iphone',
#  'param',
#  'mb',
#  'static',
#  'typeahead',
#  'eval',
#  'embedded',
#  '.ts',
#  'multiplication',
#  'atomic',
#  'readfile',
#  'ilogger',
#  'delay',
#  'jboss',
#  'applicationcontroller',
#  'nib',
#  'redraw',
#  'geo',
#  'rate',
#  'author',
#  'uibarbuttonitem',
#  'hashcode',
#  'connector',
#  'maven',
#  'autoplay',
#  'notation',
#  'revision',
#  'kubectl',
#  'tcp',
#  'shuffle',
#  'fallback',
#  'tabitem',
#  'tinymce',
#  'opera',
#  'domdocument',
#  'hibernate',
#  'bunch',
#  'ddl',
#  'hostname',
#  'uid',
#  'merge',
#  'overlap',
#  'string',
#  'fread',
#  'scope',
#  'programmatically',
#  'itemssource',
#  'sample',
#  'gamma',
#  'clipboard',
#  'libxml',
#  'nsdictionary',
#  'wsdl',
#  'speech',
#  'portal',
#  'fedora',
#  'monitoring',
#  'pager',
#  'appsettings',
#  'love',
#  'zlib',
#  '.d',
#  'switching',
#  'argumentexception',
#  'curl',
#  'gallery',
#  'docker-compose',
#  'jsch',
#  'model',
#  'self',
#  'infinite',
#  's',
#  'system',
#  'curve',
#  'handshake',
#  'razor',
#  'click',
#  'html.actionlink',
#  'azure',
#  'localization',
#  'smtp',
#  'inflate',
#  'webpack-dev-server',
#  'sink',
#  'production',
#  'cart',
#  'maven-compiler-plugin',
#  'nonetype',
#  'yahoo',
#  'spacing',
#  'cgpoint',
#  'mesh',
#  'utf',
#  'jlabel',
#  'sharing',
#  'textblock',
#  'invalidoperationexception',
#  'msmq',
#  'fwrite',
#  'formik',
#  'brush',
#  'administrator',
#  'precision',
#  'actionresult',
#  'afnetworking',
#  'dealloc',
#  'json',
#  'qwidget',
#  'timing',
#  'meter',
#  'udp',
#  'multicast',
#  'gl',
#  'facebook',
#  '-r',
#  'copy',
#  'frequency',
#  'prompt',
#  'luarocks',
#  'vertex',
#  'mp',
#  'foundation',
#  'hbitmap',
#  'inverse',
#  'comparator',
#  'hosting',
#  'hash',
#  'command',
#  'sync',
#  'isset',
#  'base',
#  'dbf',
#  'newline',
#  '.map',
#  'nsurlrequest',
#  'nix',
#  'refactoring',
#  'routing',
#  'capture',
#  'die',
#  'jdbc',
#  'robust',
#  'unsafe',
#  'javac',
#  'direct',
#  'builder',
#  'sqlalchemy',
#  'swap',
#  'ng-template',
#  'varchar',
#  'parseint',
#  'jqxhr',
#  'el',
#  'division',
#  'height',
#  'spring-aop',
#  'chmod',
#  'floor',
#  'integrity',
#  'default',
#  'measurement',
#  'hierarchical',
#  'dns',
#  'scripting',
#  'file',
#  'jpa',
#  'testng',
#  'asp.net',
#  'targeting',
#  'packagereference',
#  'arr',
#  'unchecked',
#  'aspect',
#  'datatables',
#  'cocoa',
#  'png',
#  'activation',
#  'dispatcher',
#  'text',
#  'v-model',
#  'mvvm',
#  'release',
#  'exec',
#  'casting',
#  'intellisense',
#  'receiver',
#  'webapp',
#  'rewrite',
#  'r',
#  'fragment',
#  'audio',
#  'pcm',
#  'postgresql',
#  'implementation',
#  'gulp',
#  'garbage',
#  'lm',
#  'microphone',
#  'passphrase',
#  'adc',
#  'gaussian',
#  'defined',
#  'web-inf',
#  'silent',
#  'interactive',
#  'updatesourcetrigger',
#  '.sqlclient',
#  'publickeytoken',
#  'dt',
#  'messaging',
#  'sender',
#  'primefaces',
#  'assembly',
#  'gm',
#  'publish',
#  'ctype',
#  'serializable',
#  'sigmoid',
#  'selector',
#  'python',
#  'dm',
#  '-beta',
#  'playing',
#  'processor',
#  'padding',
#  'taxonomy',
#  'mousemove',
#  'qmainwindow',
#  'bin',
#  'floating',
#  'detection',
#  'revert',
#  'noise',
#  'textview',
#  'escaping',
#  'spy',
#  'seed',
#  'regression',
#  'jira',
#  'proc',
#  'angular',
#  'sidekiq',
#  'bitrate',
#  'memset',
#  'delphi',
#  'partition',
#  'ctrl',
#  'rect',
#  'eventhandler',
#  'nvidia',
#  'equality',
#  'referer',
#  'inspect',
#  'slug',
#  'twig',
#  'fiddler',
#  'sinon',
#  'iqueryable',
#  'eventargs',
#  'hbase',
#  'receipt',
#  'provisioning',
#  'correlation',
#  'wwwroot',
#  'variant',
#  'perspective',
#  'contextmenu',
#  'alamofire',
#  'package',
#  'shiny',
#  'yuv',
#  'aws-sdk',
#  'simulate',
#  'serving',
#  'httpclient',
#  'attachment',
#  'hit',
#  'delimiter',
#  'site-packages',
#  'paragraph',
#  'finder',
#  'void',
#  'encoder',
#  'alloc',
#  'llvm',
#  'gd',
#  'vim',
#  'recreate',
#  'foreground',
#  'breakpoints',
#  'gem',
#  'sax',
#  'runtime',
#  'utility',
#  'live',
#  'nslog',
#  'fork',
#  'math',
#  'updating',
#  'tex',
#  'redefinition',
#  'xampp',
#  'toolkit',
#  'cgi',
#  'reduce',
#  'querying',
#  'pkcs',
#  'initialization',
#  'extends',
#  '.x',
#  'cakephp',
#  'menuitem',
#  'uploader',
#  'hardcode',
#  'eigen',
#  'declaration',
#  'firebase-admin',
#  'uitabbarcontroller',
#  'std',
#  'deserialization',
#  'theory',
#  'endpoint',
#  'jruby',
#  'sleep',
#  'viewport',
#  'x',
#  'nginx',
#  'backtrace',
#  'spreadsheet',
#  'console',
#  'rgba',
#  'prepare',
#  'flex',
#  'cell',
#  'wireshark',
#  'asio',
#  'wave',
#  'jersey',
#  'uicollectionviewcell',
#  'anchor',
#  'rpc',
#  'eventemitter',
#  'repository',
#  'enumeration',
#  'movieclip',
#  'teamcity',
#  'meta-inf',
#  'ionic',
#  'fopen',
#  'rsa',
#  'jinja',
#  'footer',
#  'semaphore',
#  'jsf',
#  'require',
#  'web',
#  '+',
#  'flash',
#  'ejb',
#  'websocket',
#  'javax.validation',
#  'real-time',
#  'system.drawing',
#  'vaadin',
#  'keyboard',
#  'status',
#  'basichttpbinding',
#  'setvalue',
#  'add-in',
#  'fileoutputstream',
#  'logfile',
#  'area',
#  'unicorn',
#  'hex',
#  'interface',
#  'controller',
#  'nonce',
#  'setter',
#  'fileinputstream',
#  'runnable',
#  'traversal',
#  'direction',
#  'xx',
#  'emr',
#  'transactionmanager',
#  'sorting',
#  'segue',
#  'trailing',
#  'propertyinfo',
#  'directx',
#  'notify',
#  'conda',
#  'userid',
#  'sdl',
#  'f',
#  'title',
#  'inputstream',
#  'exe',
#  'vi',
#  'webrequest',
#  'fault',
#  'perl',
#  'startup',
#  'getter',
#  'datetime',
#  'partial',
#  'ondestroy',
#  'miktex',
#  'gzip',
#  'case',
#  'alternate',
#  'unmanaged',
#  'wise',
#  'drag',
#  'crop',
#  'joomla',
#  'margin',
#  'ethernet',
#  'contenteditable',
#  'voice',
#  'spinner',
#  'virtualbox',
#  'uname',
#  'hresult',
#  'lang',
#  'filtering',
#  'transparency',
#  'locate',
#  'highlight',
#  'rename',
#  'stuff',
#  'composite',
#  'bufferedreader',
#  '.js',
#  'sqlexception',
#  'beacon',
#  'tesseract',
#  'getattr',
#  'retrofit',
#  'directory',
#  'par',
#  'react-dom',
#  'relational',
#  'arabic',
#  'sqrt',
#  'bullet',
#  'webkit',
#  'predicate',
#  'lstm',
#  'm',
#  'deque',
#  'tabindex',
#  'signature',
#  'ld',
#  'jstl',
#  'ckeditor',
#  'decltype',
#  'encoding',
#  'nan',
#  'yield',
#  'trunk',
#  'href',
#  'vault',
#  'nokogiri',
#  'slf',
#  'exception',
#  'mamp',
#  'processing',
#  'glob',
#  'textinput',
#  'treenode',
#  'map',
#  'difference',
#  'package.json',
#  'solr',
#  'flatten',
#  'kernel',
#  'asynccallback',
#  'helper',
#  'rule',
#  'position',
#  'jbutton',
#  'telnet',
#  'jsonresponse',
#  'red',
#  'lib',
#  'openssl',
#  'easyrtc',
#  'restore',
#  'setcookie',
#  'checked',
#  'fragmentmanager',
#  'datasource',
#  'stopwatch',
#  'system.configuration',
#  'memorystream',
#  'printing',
#  'ajp',
#  'caption',
#  'kerberos',
#  'profile',
#  'shadow',
#  'identifier',
#  'expansion',
#  'ipv',
#  'viewchild',
#  'jython',
#  'git',
#  'httpurlconnection',
#  'temp',
#  'hadoop',
#  'time',
#  'vpn',
#  'searchbar',
#  'scrapy',
#  'solaris',
#  'platform',
#  'scrollview',
#  'gtk',
#  'join',
#  'cache-control',
#  'photo',
#  'pseudocode',
#  'device-width',
#  'sqldatareader',
#  'wireless',
#  'fuzzy',
#  'daemon',
#  'encode',
#  'jupyter',
#  'graph',
#  'nsobject',
#  'vps',
#  'syswow',
#  'edit',
#  'mongoose',
#  'dump',
#  'identify',
#  'view',
#  'hue',
#  'adapter',
#  'textarea',
#  'gmail',
#  'keyerror',
#  'fft',
#  'beta',
#  'requirements.txt',
#  'mfc',
#  'mozilla',
#  'gettype',
#  'gcc',
#  'unzip',
#  'trim',
#  'recompile',
#  'intercept',
#  'relativesource',
#  '.xml',
#  'nunit',
#  'onerror',
#  'xsd',
#  'prototype',
#  'uikit',
#  'express',
#  'share',
#  'pid',
#  'cython',
#  'signed',
#  'memcached',
#  'jtextarea',
#  'automation',
#  'powershell',
#  'browser',
#  'paint',
#  'nightmare',
#  'outlet',
#  'mage',
#  'palette',
#  'iterator',
#  'api',
#  'terminal',
#  'extend',
#  'contact',
#  'strip',
#  'frame',
#  'docx',
#  'timespan',
#  'client',
#  'eventtrigger',
#  'dockerfile',
#  'observablecollection',
#  'webclient',
#  'subquery',
#  'system.text',
#  'parquet',
#  'enzyme',
#  'separator',
#  'n',
#  'transmission',
#  'nsurl',
#  'service',
#  'jquery',
#  'ping',
#  'subdirectory',
#  'user-agent',
#  'orange',
#  'buffering',
#  'intranet',
#  'generator',
#  'cryptography',
#  'pwd',
#  'undefined',
#  'screen',
#  'cat',
#  'xacml',
#  'add-on',
#  'carousel',
#  'ninject',
#  'allocator',
#  'interpolation',
#  'selection',
#  'listview',
#  'strlen',
#  'key',
#  'uiimagepickercontroller',
#  'auto',
#  'admin',
#  'stringbuffer',
#  'java',
#  'wikipedia',
#  'id',
#  'undo',
#  'legend',
#  'lightbox',
#  'deflate',
#  'remoting',
#  'onclicklistener',
#  'locking',
#  'jtable',
#  'cultureinfo',
#  'airflow',
#  'setup.py',
#  'ram',
#  'wamp',
#  'ml',
#  'runtimeexception',
#  'typeid',
#  'device',
#  'avatar',
#  'wicket',
#  'overlapping',
#  'draw',
#  'hikaricp',
#  'ttl',
#  'settimeout',
#  'arraylist',
#  'subnet',
#  'vpc',
#  'staticresource',
#  'handler',
#  'css-loader',
#  'iteration',
#  'root',
#  'transparent',
#  'app',
#  'binding',
#  'getstring',
#  'feedback',
#  'cut',
#  'transfer',
#  'collation',
#  'actionscript',
#  'material-ui',
#  'expo',
#  'double',
#  'datepicker',
#  'continue',
#  'dbconnection',
#  'push',
#  'systemd',
#  'locationmanager',
#  'accordion',
#  'pyqt',
#  'nameerror',
#  'instant',
#  'postman',
#  'big',
#  'glassfish',
#  'ansible',
#  'datacontract',
#  'dpi',
#  'url-pattern',
#  'similarity',
#  'uiviewcontroller',
#  'role',
#  'mariadb',
#  'axios',
#  'subtotal',
#  'ioctl',
#  'datamember',
#  'appender',
#  'tar',
#  'payment',
#  'qlabel',
#  'format',
#  'findall',
#  'enums',
#  'background',
#  'capybara',
#  'initializer',
#  'tooltip',
#  'wpf',
#  'jsr',
#  'serversocket',
#  'isenabled',
#  'apollo',
#  'urn',
#  '.htaccess',
#  'dynamic',
#  'slice',
#  'vagrant',
#  'layer',
#  'resolve',
#  'wc',
#  'cmp',
#  'headless',
#  'pull',
#  'happy',
#  'reshape',
#  '.doc',
#  'objectmapper',
#  'nested',
#  'destroy',
#  'suffix',
#  'md',
#  'ogg',
#  'celery',
#  'drawerlayout',
#  'webhttpbinding',
#  'datastore',
#  'backcolor',
#  'addition',
#  'conditional',
#  'bind',
#  'redis',
#  'build.gradle',
#  'laravel',
#  'prefix',
#  'servlet-mapping',
#  'autorelease',
#  'embed',
#  'adobe',
#  'formatting',
#  'lnk',
#  'abc',
#  'deadlock',
#  'singleton',
#  'web.xml',
#  'function',
#  'woff',
#  'timeline',
#  'salt',
#  'lisp',
#  'rest',
#  'wait',
#  'rpm',
#  'shrink',
#  'q',
#  'uart',
#  'prediction',
#  'wildfly',
#  'dotenv',
#  'p',
#  'tuples',
#  'notnull',
#  'timezone',
#  'offset',
#  'solver',
#  'tracking',
#  'clone',
#  'security',
#  'webview',
#  'edt',
#  'motion',
#  'wcf',
#  'comp',
#  'jms',
#  'bytecode',
#  'zone',
#  'computation',
#  'simulator',
#  'nvarchar',
#  'ingres',
#  'hashmap',
#  'continuous',
#  'load',
#  'slash',
#  'boot',
#  'mainframe',
#  'loading',
#  'core',
#  'schema',
#  'glm',
#  'nullpointerexception',
#  'show',
#  'openshift',
#  'rendering',
#  'xmlserializer',
#  'future',
#  'raise',
#  'typo',
#  'gp',
#  'swing',
#  'atlas',
#  'percentage',
#  'schannel',
#  'cl',
#  'artifact',
#  'timer',
#  'vector',
#  'replication',
#  'subscribe',
#  'populate',
#  'synchronized',
#  'hierarchy',
#  'stroke',
#  'border',
#  'transformation',
#  'random',
#  'amd',
#  'winforms',
#  'pythonpath',
#  'textbox',
#  'string.format',
#  '.json',
#  'principal',
#  'universal',
#  'onstart',
#  'word',
#  'publishing',
#  'key-value',
#  ...}

# %%
too_freq_words = [w for w in list_most_freq_words[:800] if w not in elems_not_to_drop_high_freq]
len(too_freq_words)
# Out:
# 415

# %%
too_freq_words
# Out:
# ['first',
#  'px',
#  'could',
#  'something',
#  'working',
#  'column',
#  'info',
#  'change',
#  'thanks',
#  'const',
#  'however',
#  'found',
#  'main',
#  'org.apache',
#  'content',
#  'org.springframework',
#  'number',
#  'query',
#  'update',
#  'used',
#  'style',
#  'issue',
#  'source',
#  'event',
#  'library',
#  'let',
#  'print',
#  'two',
#  'dependency',
#  'running',
#  'able',
#  'link',
#  'start',
#  'look',
#  'different',
#  'override',
#  'please',
#  'read',
#  'program',
#  'fine',
#  'right',
#  'password',
#  'created',
#  'li',
#  'getting',
#  'access',
#  'thread',
#  'without',
#  'possible',
#  'body',
#  'seems',
#  'another',
#  'context',
#  'idea',
#  'def',
#  'still',
#  'variable',
#  'span',
#  'open',
#  'second',
#  'component',
#  'index',
#  'cannot',
#  'anyone',
#  'usr',
#  'thing',
#  'even',
#  'parameter',
#  'order',
#  'sure',
#  'none',
#  'failed',
#  'artifactid',
#  'simple',
#  'node',
#  'groupid',
#  'check',
#  'wrong',
#  'home',
#  '.org',
#  'done',
#  'username',
#  'address',
#  'called',
#  'part',
#  'inside',
#  '.jar',
#  'debug',
#  'xmlns',
#  'already',
#  'information',
#  'instead',
#  'resource',
#  'tag',
#  '.internal',
#  'compile',
#  'etc',
#  'control',
#  'write',
#  'since',
#  'every',
#  'give',
#  'answer',
#  'long',
#  'current',
#  'added',
#  'think',
#  'well',
#  'catch',
#  'custom',
#  'folder',
#  'say',
#  'implement',
#  'install',
#  'left',
#  'java.lang',
#  'really',
#  'th',
#  'currently',
#  'login',
#  'via',
#  'top',
#  'bean',
#  'img',
#  'many',
#  'loop',
#  'container',
#  'may',
#  'br',
#  'last',
#  'child',
#  'correct',
#  '.release',
#  'note',
#  'err',
#  'site',
#  'based',
#  'framework',
#  'description',
#  'google',
#  'multiple',
#  'pa',
#  'group',
#  'much',
#  'looking',
#  'step',
#  'everything',
#  'creating',
#  'within',
#  '#include',
#  'far',
#  'float',
#  'understand',
#  'attribute',
#  '.invoke',
#  'plugin',
#  'must',
#  'best',
#  'appreciated',
#  'seem',
#  'good',
#  'missing',
#  '.core',
#  'lot',
#  'tool',
#  'always',
#  'advance',
#  'support',
#  'given',
#  'convert',
#  'expected',
#  'success',
#  'specific',
#  'warning',
#  'detail',
#  'website',
#  'bar',
#  'delete',
#  'tab',
#  'nothing',
#  'better',
#  'similar',
#  'anything',
#  'installed',
#  'remove',
#  'someone',
#  'comment',
#  '.println',
#  'single',
#  'either',
#  'val',
#  'argument',
#  'node_modules',
#  'thank',
#  'keep',
#  'around',
#  'studio',
#  'filename',
#  'correctly',
#  '.web',
#  'actually',
#  '.catalina',
#  'come',
#  'available',
#  'going',
#  'yes',
#  'day',
#  'setup',
#  'machine',
#  'category',
#  'made',
#  'await',
#  'route',
#  'adding',
#  'statement',
#  'fix',
#  'section',
#  'foo',
#  'async',
#  'feature',
#  'empty',
#  'side',
#  'activity',
#  '.add',
#  'ok',
#  'close',
#  'visual',
#  'length',
#  'ui',
#  'bool',
#  'chrome',
#  'asp',
#  'col',
#  'might',
#  'approach',
#  'unknown',
#  'level',
#  'place',
#  'socket',
#  'namespace',
#  'job',
#  'entry',
#  'i++',
#  'stored',
#  'successfully',
#  'full',
#  'loaded',
#  'suggestion',
#  'ul',
#  'language',
#  'str',
#  'df',
#  'tell',
#  'nil',
#  'solve',
#  'changed',
#  '.run',
#  'unable',
#  'thought',
#  '.support',
#  'network',
#  'though',
#  'maybe',
#  'collection',
#  'cache',
#  'org.hibernate',
#  'unit',
#  'writing',
#  'extension',
#  'icon',
#  'calling',
#  'started',
#  'customer',
#  'layout_height',
#  'layout_width',
#  'e.g',
#  'written',
#  'font',
#  'domain',
#  'i.e',
#  '+id',
#  'kind',
#  'cause',
#  'pointer',
#  'hello',
#  'allow',
#  'reading',
#  'never',
#  'person',
#  '.beans',
#  'sort',
#  'r.id',
#  'properly',
#  'total',
#  '.factory',
#  'intent',
#  'small',
#  'several',
#  'stop',
#  'react',
#  'achieve',
#  'actual',
#  'org.gradle',
#  '.tostring',
#  '.text',
#  'sent',
#  'androidruntime',
#  'basically',
#  'follows',
#  'standard',
#  'building',
#  'com.sun',
#  'mvc',
#  'sub',
#  'goal',
#  'starting',
#  'permission',
#  'remote',
#  'simply',
#  'making',
#  'pattern',
#  '.http',
#  'directly',
#  'invalid',
#  'original',
#  'related',
#  'worked',
#  'switch',
#  'provide',
#  'valid',
#  'happens',
#  'whole',
#  'shown',
#  'updated',
#  'com.google',
#  'microsoft',
#  'returned',
#  'notification',
#  'fails',
#  'params',
#  'org.eclipse',
#  'dim',
#  'compiler',
#  '.execute',
#  'trigger',
#  'obj',
#  'asset',
#  'com.android',
#  'development',
#  'active',
#  'large',
#  'tutorial',
#  'rather',
#  '.value',
#  'common',
#  'normal',
#  'dev',
#  'match_parent',
#  'clear',
#  '.v',
#  'symbol',
#  'amount',
#  'receive',
#  'exist',
#  'per',
#  'appears',
#  'play',
#  'old',
#  'manually',
#  '.final',
#  'phone',
#  'yet',
#  'month',
#  'wrap_content',
#  'whether',
#  'quite',
#  'received',
#  'medium',
#  'bottom',
#  'automatically',
#  'developer',
#  'existing',
#  'flag',
#  'enabled',
#  'caused',
#  'register',
#  'little',
#  'transaction',
#  'define',
#  'provided',
#  'begin',
#  'wondering',
#  'attempt',
#  'separate',
#  'complete',
#  'due',
#  'needed',
#  'seen',
#  'www.w',
#  '.servlet',
#  'prop',
#  'sending',
#  'ex',
#  'pretty',
#  'card',
#  'rail',
#  'displayed',
#  'previous',
#  'great',
#  'exactly',
#  '.jdbc',
#  'env',
#  'game',
#  'engine',
#  'course']

# %%
too_freq_words_df = pd.DataFrame({"words" : too_freq_words})
# Out:
#           words
# 0           new
# 1         using
# 2          name
# 3         error
# 4          data
# 5         value
# 6          like
# 7           use
# 8           div
# 9          work
# 10            #
# 11         true
# 12         want
# 13        would
# 14          one
# 15       method
# 16  application
# 17         need
# 18      problem
# 19          way
# 20         test
# 21       trying
# 22        table
# 23       script
# 24        false
# 25          run
# 26        tried
# 27         page
# 28    following
# 29       result
# 30         know
# 31         also
# 32       create
# 33         .com
# 34      example
# 35         make
# 36         help
# 37          end
# 38       option
# 39           td
# 40          try
# 41            _
# 42     property
# 43         item
# 44         form
# 45         else
# 46     question
# 47          see

# %%
too_freq_words_df.to_csv("data/cleaned/too_freq_words.csv", index=False)
too_freq_words_df

# %%
too_freq_words_2 = pd.read_csv('data/cleaned/too_freq_words.csv')
too_freq_words_2
# Out:
#           words
# 0           new
# 1         using
# 2          name
# 3         error
# 4          data
# 5         value
# 6          like
# 7           use
# 8           div
# 9          work
# 10            #
# 11         true
# 12         want
# 13        would
# 14          one
# 15       method
# 16  application
# 17         need
# 18      problem
# 19          way
# 20         test
# 21       trying
# 22        table
# 23       script
# 24        false
# 25          run
# 26        tried
# 27         page
# 28    following
# 29       result
# 30         know
# 31         also
# 32       create
# 33         .com
# 34      example
# 35         make
# 36         help
# 37          end
# 38       option
# 39           td
# 40          try
# 41            _
# 42     property
# 43         item
# 44         form
# 45         else
# 46     question
# 47          see

# %%
def process_text_2(doc,
                   rejoin=False,
                   stem_or_lem=2
                 ) :
    """function of text processing

    positional arguments:
    ----------------------
    doc: str : the document (aka a text in str format) to process

    opt arguments:
    ---------------------
    rejoin: bool : if True return a string else return a list of tokens

    return:
    --------------------
    a string (if rejoin is True) or a list of tokens
    """

    #tokenizer
    tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+')
    raw_tokens_list = tokenizer.tokenize(doc)

    #############################################################################################
    # stop words:
    english_stop_words=nltk.corpus.stopwords.words('English')
    cleaned_tokens_list = [word for word in raw_tokens_list if word not in english_stop_words]

    #############################################################################################

    #lemmatizer
    if stem_or_lem == 1:
        trans = SnowballStemmer("english")
        trans_text = [trans.stem(word) for word in cleaned_tokens_list]
    if stem_or_lem == 2:
        trans = WordNetLemmatizer()
        trans_text = [trans.lemmatize(word) for word in cleaned_tokens_list]
    else:
        trans_text = cleaned_tokens_list

    most_freq = [w for w in trans_text if w not in too_freq_words]

    if rejoin:
        return " ".join(most_freq)

    return most_freq

# %%
def final_clean_2(doc):
    new_doc = process_text_2(doc,
                           rejoin=True,
                           )
    return new_doc

# %%
df
# Out:
#                                                    Title  \
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3               managing data access simple winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation currently pr...
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .internal .resolve .artifactnotfoun...
#
#                                                     Body  \
# 0      way sandbox linux process certain directory gi...
# 1      jframe two panel one panel draw line working m...
# 2      expert network security pardon question smart ...
# 3      simple winforms data entry app us sqlite alway...
# 4      basic node.js app trying get ground using expr...
# ...                                                  ...
# 49995  using ssis tool ole db downloading data vertic...
# 49996  using f uploading file already created bucket ...
# 49997  following jupyter notebook course hit upon err...
# 49998  json wanted update field process my-process po...
# 49999  using version firebase google play service bui...
#
#                                                     Tags  \
# 0                   linux ubuntu process sandbox selinux
# 1                      java graphics jframe jpanel paint
# 2        security ssh ssh-keys openssh man-in-the-middle
# 3             c# winforms sqlite datatable sqlconnection
# 4                javascript html node.js mongodb express
# ...                                                  ...
# 49995  sql-server ssas oledb sql-server-data-tools ve...
# 49996  python amazon-web-services amazon-s boto pytho...
# 49997  python machine-learning deep-learning pytorch ...
# 49998               java json rest json-patch http-patch
# 49999  android android-studio android-gradle-plugin g...
#
#                                              _clean_tags  _len_body  \
# 0             [linux, ubuntu, process, sandbox, selinux]        526
# 1                [java, graphics, jframe, jpanel, paint]       2969
# 2      [security, ssh, ssh-keys, openssh, man-in-the-...        447
# 3       [c#, winforms, sqlite, datatable, sqlconnection]       2537
# 4          [javascript, html, node.js, mongodb, express]        335
# ...                                                  ...        ...
# 49995  [sql-server, ssas, oledb, sql-server-data-tool...        206
# 49996  [python, amazon-web-services, amazon-s, boto, ...        301
# 49997  [python, machine-learning, deep-learning, pyto...        908
# 49998         [java, json, rest, json-patch, http-patch]        645
# 49999  [android, android-studio, android-gradle-plugi...      27209
#
#                                                   Body_2  _len_body_2
# 0      sandbox linux process certain directory give p...          494
# 1      jframe two panel panel draw line working minim...         2874
# 2      expert network security pardon question smart ...          447
# 3      simple winforms entry app u sqlite always sing...         2421
# 4      basic node.js app trying get ground using expr...          320
# ...                                                  ...          ...
# 49995  using ssis tool ole db downloading vertica dat...          196
# 49996  using f uploading file already created bucket ...          284
# 49997  following jupyter notebook course hit upon lin...          831
# 49998  json wanted update field process my-process po...          606
# 49999  using version firebase google play service bui...        27187
#
# [50000 rows x 7 columns]

# %% [markdown]
# ### 📌 HERE

# %%
df['Body_2'] = df['Body'].parallel_apply(lambda x : final_clean_2(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df['Title_2'] = df['Title_2'].parallel_apply(lambda x : final_clean_2(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df
# Out:
#                                                    Title  \
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3               managing data access simple winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation currently pr...
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .internal .resolve .artifactnotfoun...
#
#                                                     Body  \
# 0      way sandbox linux process certain directory gi...
# 1      jframe two panel one panel draw line working m...
# 2      expert network security pardon question smart ...
# 3      simple winforms data entry app us sqlite alway...
# 4      basic node.js app trying get ground using expr...
# ...                                                  ...
# 49995  using ssis tool ole db downloading data vertic...
# 49996  using f uploading file already created bucket ...
# 49997  following jupyter notebook course hit upon err...
# 49998  json wanted update field process my-process po...
# 49999  using version firebase google play service bui...
#
#                                                     Tags  \
# 0                   linux ubuntu process sandbox selinux
# 1                      java graphics jframe jpanel paint
# 2        security ssh ssh-keys openssh man-in-the-middle
# 3             c# winforms sqlite datatable sqlconnection
# 4                javascript html node.js mongodb express
# ...                                                  ...
# 49995  sql-server ssas oledb sql-server-data-tools ve...
# 49996  python amazon-web-services amazon-s boto pytho...
# 49997  python machine-learning deep-learning pytorch ...
# 49998               java json rest json-patch http-patch
# 49999  android android-studio android-gradle-plugin g...
#
#                                              _clean_tags  _len_body  \
# 0             [linux, ubuntu, process, sandbox, selinux]        526
# 1                [java, graphics, jframe, jpanel, paint]       2969
# 2      [security, ssh, ssh-keys, openssh, man-in-the-...        447
# 3       [c#, winforms, sqlite, datatable, sqlconnection]       2537
# 4          [javascript, html, node.js, mongodb, express]        335
# ...                                                  ...        ...
# 49995  [sql-server, ssas, oledb, sql-server-data-tool...        206
# 49996  [python, amazon-web-services, amazon-s, boto, ...        301
# 49997  [python, machine-learning, deep-learning, pyto...        908
# 49998         [java, json, rest, json-patch, http-patch]        645
# 49999  [android, android-studio, android-gradle-plugi...      27209
#
#                                                   Body_2  _len_body_2
# 0      sandbox linux process certain directory give p...          494
# 1      jframe two panel panel draw line working minim...         2874
# 2      expert network security pardon smart automatin...          447
# 3      simple winforms entry app u sqlite always sing...         2421
# 4      basic node.js app get ground express framework...          320
# ...                                                  ...          ...
# 49995  ssis tool ole db downloading vertica database ...          196
# 49996  f uploading file already created bucket deleti...          284
# 49997  jupyter notebook course hit upon line cnn_lear...          831
# 49998  json wanted update field process my-process po...          606
# 49999  version firebase google play service build sta...        27187
#
# [50000 rows x 7 columns]

# %%
tmp = df.Body_2.str.len()

# %%
df["_len_body_2"] = tmp

# %%
df
# Out:
#                                                    Title  \
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3               managing data access simple winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation currently pr...
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .internal .resolve .artifactnotfoun...
#
#                                                     Body  \
# 0      way sandbox linux process certain directory gi...
# 1      jframe two panel one panel draw line working m...
# 2      expert network security pardon question smart ...
# 3      simple winforms data entry app us sqlite alway...
# 4      basic node.js app trying get ground using expr...
# ...                                                  ...
# 49995  using ssis tool ole db downloading data vertic...
# 49996  using f uploading file already created bucket ...
# 49997  following jupyter notebook course hit upon err...
# 49998  json wanted update field process my-process po...
# 49999  using version firebase google play service bui...
#
#                                                     Tags  \
# 0                   linux ubuntu process sandbox selinux
# 1                      java graphics jframe jpanel paint
# 2        security ssh ssh-keys openssh man-in-the-middle
# 3             c# winforms sqlite datatable sqlconnection
# 4                javascript html node.js mongodb express
# ...                                                  ...
# 49995  sql-server ssas oledb sql-server-data-tools ve...
# 49996  python amazon-web-services amazon-s boto pytho...
# 49997  python machine-learning deep-learning pytorch ...
# 49998               java json rest json-patch http-patch
# 49999  android android-studio android-gradle-plugin g...
#
#                                              _clean_tags  _len_body  \
# 0             [linux, ubuntu, process, sandbox, selinux]        526
# 1                [java, graphics, jframe, jpanel, paint]       2969
# 2      [security, ssh, ssh-keys, openssh, man-in-the-...        447
# 3       [c#, winforms, sqlite, datatable, sqlconnection]       2537
# 4          [javascript, html, node.js, mongodb, express]        335
# ...                                                  ...        ...
# 49995  [sql-server, ssas, oledb, sql-server-data-tool...        206
# 49996  [python, amazon-web-services, amazon-s, boto, ...        301
# 49997  [python, machine-learning, deep-learning, pyto...        908
# 49998         [java, json, rest, json-patch, http-patch]        645
# 49999  [android, android-studio, android-gradle-plugi...      27209
#
#                                                   Body_2  _len_body_2
# 0      sandbox linux process certain directory give p...          462
# 1      jframe two panel panel draw line working minim...         2855
# 2      expert network security pardon smart automatin...          414
# 3      simple winforms entry app u sqlite always sing...         2382
# 4      basic node.js app get ground express framework...          292
# ...                                                  ...          ...
# 49995  ssis tool ole db downloading vertica database ...          186
# 49996  f uploading file already created bucket deleti...          268
# 49997  jupyter notebook course hit upon line cnn_lear...          781
# 49998  json wanted update field process my-process po...          566
# 49999  version firebase google play service build sta...        27143
#
# [50000 rows x 7 columns]

# %%
df['Body'] = df['Body_2']
df.head(5)

# %%
df['_len_body'] = df['_len_body_2']
df.head(5)

# %%
df = df.drop(['Body_2','_len_body_2'], axis=1)
df.head(5)

# %%
df.Body_2.sample(2)

# %%
df

# %%
raw_corpus = " ".join(df.Body_2.values)
raw_corpus[:1000]
# Out:
# 'sandbox linux process certain directory give process exclusive rw access dir temporary working directory start e.g python another scripting tool write directory without limiting much functionality process access read directory except superusers course sandbox web service basically allows user arbitrary code currently authorization software process linux user user cannot harm system temporary private working directory write read file protected user webservice jframe two panel panel draw line working minimized window java program maximized line drew different repainted different place anyone idea lock painting minimize screw drawing thank import java.awt import javax.swing import java.awt .event import java.io import java.util import javax.imageio .imageio import java.awt .graphics import java.awt .image .bufferedimage import java.io .file class jframepaint extends jframe implement actionlistener implement actionlistener public static int activa public static jbutton drawing jbutton draw'

# %%
tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+')
raw_tokens_body = tokenizer.tokenize(raw_corpus)
raw_tokens_body[:30]
# Out:
# ['sandbox',
#  'linux',
#  'process',
#  'certain',
#  'directory',
#  'give',
#  'process',
#  'exclusive',
#  'rw',
#  'access',
#  'dir',
#  'temporary',
#  'working',
#  'directory',
#  'start',
#  'e.g',
#  'python',
#  'another',
#  'scripting',
#  'tool',
#  'write',
#  'directory',
#  'without',
#  'limiting',
#  'much',
#  'functionality',
#  'process',
#  'access',
#  'read',
#  'directory']

# %%
display_tokens_info(raw_tokens_body)
# Out:
# nb tokens 6235418, nb tokens uniques 468703
# ['sandbox', 'linux', 'process', 'certain', 'directory', 'give', 'process', 'exclusive', 'rw', 'access', 'dir', 'temporary', 'working', 'directory', 'start', 'e.g', 'python', 'another', 'scripting', 'tool', 'write', 'directory', 'without', 'limiting', 'much', 'functionality', 'process', 'access', 'read', 'directory']

# %%
df.to_csv("data/cleaned/df_process_text_3.csv", index=False)

# %% [markdown]
# #### 2.4 Preliminary Analysis of Frequency

# %%
raw_corpus_text = " ".join(df.Body_2.values)
raw_corpus_text[:1000]
# Out:
# 'sandbox linux process certain directory give process exclusive rw access dir temporary working directory start e.g python another scripting tool write directory without limiting much functionality process access read directory except superusers course sandbox web service basically allows user arbitrary code currently authorization software process linux user user cannot harm system temporary private working directory write read file protected user webservice jframe two panel panel draw line working minimized window java program maximized line drew different repainted different place anyone idea lock painting minimize screw drawing thank import java.awt import javax.swing import java.awt .event import java.io import java.util import javax.imageio .imageio import java.awt .graphics import java.awt .image .bufferedimage import java.io .file class jframepaint extends jframe implement actionlistener implement actionlistener public static int activa public static jbutton drawing jbutton draw'

# %%
tokenizer = nltk.RegexpTokenizer(r'[a-zA_\-+#]*\.?[a-zA_\+#]+')
raw_tokens_tags= tokenizer.tokenize(raw_corpus_tags)
raw_tokens_text = tokenizer.tokenize(raw_corpus_text)

# %%
display_tokens_info(raw_tokens_tags)
# Out:
# nb tokens 254932, nb tokens uniques 18044
# ['linux', 'ubuntu', 'process', 'sandbox', 'selinux', 'java', 'graphics', 'jframe', 'jpanel', 'paint', 'security', 'ssh', 'ssh-keys', 'openssh', 'man-in-the-middle', 'c#', 'winforms', 'sqlite', 'datatable', 'sqlconnection', 'javascript', 'html', 'node.js', 'mongodb', 'express', 'node.js', 'express', 'routes', 'nested-routes', 'module-export']

# %%
display_tokens_info(raw_tokens_text)
# Out:
# nb tokens 6235418, nb tokens uniques 468703
# ['sandbox', 'linux', 'process', 'certain', 'directory', 'give', 'process', 'exclusive', 'rw', 'access', 'dir', 'temporary', 'working', 'directory', 'start', 'e.g', 'python', 'another', 'scripting', 'tool', 'write', 'directory', 'without', 'limiting', 'much', 'functionality', 'process', 'access', 'read', 'directory']

# %%
tmp_text= pd.Series(raw_tokens_text).value_counts()
tmp_text[tmp_text > 50]
# Out:
# class          43146
# file           38885
# string         34498
# code           32255
# public         31995
#                ...
# .closest          51
# ajp               51
# .repo             51
# app.xaml          51
# .jspservlet       51
# Length: 9024, dtype: int64

# %%
list_most_freq_words = list((tmp_text[tmp_text > 50]).index)
len(list_most_freq_words)
# Out:
# 9024

# %%
list_most_freq_words[:60]
# Out:
# ['class',
#  'file',
#  'string',
#  'code',
#  'public',
#  '+',
#  'get',
#  'return',
#  'x',
#  'function',
#  'id',
#  'http',
#  'c',
#  'user',
#  'type',
#  'var',
#  'int',
#  'import',
#  'e',
#  'set',
#  'android',
#  'b',
#  'object',
#  'app',
#  'server',
#  'void',
#  'null',
#  'text',
#  'image',
#  'version',
#  'f',
#  'n',
#  'private',
#  'line',
#  'list',
#  'time',
#  'button',
#  'p',
#  'project',
#  'request',
#  'u',
#  'input',
#  'url',
#  'message',
#  'call',
#  'view',
#  'array',
#  'add',
#  'key',
#  'window',
#  'lib',
#  'service',
#  'row',
#  'html',
#  'database',
#  'first',
#  'px',
#  'could',
#  'something',
#  'python']

# %%
elems_not_to_drop_high_freq = set(list_most_freq_words) & set(list_tags_words)
len(elems_not_to_drop_high_freq)
# Out:
# 2821

# %%
elems_not_to_drop_high_freq
# Out:
# {'suspend',
#  'argv',
#  'tensorboard',
#  'synchronous',
#  'xamarin.forms',
#  'xmlhttprequest',
#  'pow',
#  'zip',
#  'pca',
#  'fill',
#  'friend',
#  'xmlwriter',
#  'hdfs',
#  'report',
#  'observable',
#  'session',
#  'imagedata',
#  'flat',
#  'graphql',
#  'keycode',
#  'playback',
#  'navbar',
#  'nsdate',
#  'combobox',
#  'blueprint',
#  'lambda',
#  'chai',
#  'httpcontext',
#  'redirect',
#  'yaml',
#  'bluetooth',
#  'clause',
#  'rack',
#  'body-parser',
#  'block',
#  'nm',
#  'evaluation',
#  'dropbox',
#  'lookup',
#  'forum',
#  'protection',
#  'reader',
#  'osc',
#  'permutation',
#  'storage',
#  'transient',
#  'refer',
#  'gemfile',
#  'iostream',
#  'iboutlet',
#  'taglib',
#  'keyup',
#  'built-in',
#  'z-index',
#  'jta',
#  'dart',
#  'pad',
#  'code',
#  'mov',
#  'support-v',
#  'keyvaluepair',
#  '.datatable',
#  'geometry',
#  'uniform',
#  'cpu',
#  'moq',
#  'uiapplication',
#  'sam',
#  'wsse',
#  'region',
#  'pack',
#  'dimension',
#  'system.data',
#  'cassandra',
#  'applet',
#  'ip',
#  'logstash',
#  'ghc',
#  'recording',
#  'psycopg',
#  'tcpclient',
#  'hyperlink',
#  'uinavigationcontroller',
#  'required',
#  'sqlcommand',
#  'interceptor',
#  'get',
#  'lodash',
#  'plot',
#  'module',
#  'indexed',
#  'alt',
#  'elevation',
#  'throwable',
#  'nsfetchedresultscontroller',
#  'review',
#  'controltemplate',
#  'meta',
#  'glib',
#  'appdata',
#  'collect',
#  'head',
#  'nserror',
#  'ipad',
#  'richtextbox',
#  'scanf',
#  'printf',
#  'dateadd',
#  'positioning',
#  'mmap',
#  'struct',
#  'minimize',
#  'sidebar',
#  'modelattribute',
#  'put',
#  'cp',
#  'textfield',
#  'phpmailer',
#  'analysis',
#  'shader',
#  'combine',
#  'tfs',
#  'csv',
#  'ear',
#  'geolocation',
#  'scaling',
#  'alignment',
#  'csrf',
#  'xpath',
#  'encryption',
#  'vue.js',
#  'mocking',
#  'touch',
#  'mex',
#  'find',
#  '.concurrent',
#  'urlrequest',
#  'imagemagick',
#  'intel',
#  'application.properties',
#  'relaycommand',
#  'state',
#  'gravity',
#  'numpy',
#  'oftype',
#  'alarm',
#  'avx',
#  '.post',
#  'fancybox',
#  'swagger',
#  'multiprocessing',
#  'sudo',
#  'typeof',
#  'sqldataadapter',
#  'terraform',
#  'xmldocument',
#  'inputstreamreader',
#  'keystore',
#  'uitableview',
#  'uicollectionview',
#  'iphone',
#  'param',
#  'mb',
#  'static',
#  'typeahead',
#  'eval',
#  'embedded',
#  '.ts',
#  'multiplication',
#  'atomic',
#  'readfile',
#  'ilogger',
#  'delay',
#  'jboss',
#  'applicationcontroller',
#  'nib',
#  'redraw',
#  'geo',
#  'rate',
#  'author',
#  'uibarbuttonitem',
#  'hashcode',
#  'connector',
#  'maven',
#  'autoplay',
#  'notation',
#  'revision',
#  'kubectl',
#  'tcp',
#  'shuffle',
#  'fallback',
#  'tabitem',
#  'tinymce',
#  'opera',
#  'domdocument',
#  'hibernate',
#  'bunch',
#  'ddl',
#  'hostname',
#  'uid',
#  'merge',
#  'overlap',
#  'string',
#  'fread',
#  'scope',
#  'programmatically',
#  'itemssource',
#  'sample',
#  'gamma',
#  'clipboard',
#  'libxml',
#  'nsdictionary',
#  'wsdl',
#  'speech',
#  'portal',
#  'fedora',
#  'monitoring',
#  'pager',
#  'appsettings',
#  'love',
#  'zlib',
#  '.d',
#  'switching',
#  'argumentexception',
#  'curl',
#  'gallery',
#  'docker-compose',
#  'jsch',
#  'model',
#  'self',
#  'infinite',
#  'system',
#  'curve',
#  'handshake',
#  'razor',
#  'click',
#  'html.actionlink',
#  'azure',
#  'localization',
#  'smtp',
#  'inflate',
#  'webpack-dev-server',
#  'sink',
#  'production',
#  'cart',
#  'maven-compiler-plugin',
#  'nonetype',
#  'yahoo',
#  'spacing',
#  'cgpoint',
#  'mesh',
#  'utf',
#  'jlabel',
#  'sharing',
#  'textblock',
#  'invalidoperationexception',
#  'msmq',
#  'fwrite',
#  'formik',
#  'brush',
#  'administrator',
#  'precision',
#  'actionresult',
#  'afnetworking',
#  'dealloc',
#  'json',
#  'qwidget',
#  'timing',
#  'meter',
#  'udp',
#  'multicast',
#  'gl',
#  'facebook',
#  '-r',
#  'copy',
#  'frequency',
#  'prompt',
#  'luarocks',
#  'vertex',
#  'mp',
#  'foundation',
#  'hbitmap',
#  'inverse',
#  'comparator',
#  'hosting',
#  'hash',
#  'command',
#  'sync',
#  'isset',
#  'base',
#  'dbf',
#  'newline',
#  '.map',
#  'nsurlrequest',
#  'nix',
#  'refactoring',
#  'routing',
#  'capture',
#  'die',
#  'robust',
#  'jdbc',
#  'unsafe',
#  'javac',
#  'direct',
#  'builder',
#  'sqlalchemy',
#  'swap',
#  'ng-template',
#  'varchar',
#  'parseint',
#  'jqxhr',
#  'el',
#  'division',
#  'height',
#  'spring-aop',
#  'chmod',
#  'floor',
#  'integrity',
#  'default',
#  'measurement',
#  'hierarchical',
#  'dns',
#  'scripting',
#  'file',
#  'jpa',
#  'testng',
#  'asp.net',
#  'targeting',
#  'packagereference',
#  'arr',
#  'unchecked',
#  'aspect',
#  'datatables',
#  'cocoa',
#  'png',
#  'activation',
#  'dispatcher',
#  'text',
#  'v-model',
#  'mvvm',
#  'release',
#  'exec',
#  'casting',
#  'intellisense',
#  'receiver',
#  'webapp',
#  'rewrite',
#  'r',
#  'fragment',
#  'audio',
#  'pcm',
#  'postgresql',
#  'implementation',
#  'gulp',
#  'garbage',
#  'lm',
#  'microphone',
#  'passphrase',
#  'adc',
#  'gaussian',
#  'defined',
#  'web-inf',
#  'silent',
#  'interactive',
#  'updatesourcetrigger',
#  '.sqlclient',
#  'publickeytoken',
#  'dt',
#  'messaging',
#  'sender',
#  'primefaces',
#  'assembly',
#  'gm',
#  'publish',
#  'ctype',
#  'serializable',
#  'sigmoid',
#  'selector',
#  'python',
#  'dm',
#  '-beta',
#  'playing',
#  'processor',
#  'padding',
#  'taxonomy',
#  'mousemove',
#  'qmainwindow',
#  'bin',
#  'floating',
#  'detection',
#  'revert',
#  'noise',
#  'textview',
#  'escaping',
#  'spy',
#  'seed',
#  'regression',
#  'jira',
#  'proc',
#  'angular',
#  'sidekiq',
#  'bitrate',
#  'memset',
#  'delphi',
#  'partition',
#  'ctrl',
#  'rect',
#  'eventhandler',
#  'nvidia',
#  'equality',
#  'referer',
#  'inspect',
#  'slug',
#  'twig',
#  'fiddler',
#  'sinon',
#  'iqueryable',
#  'eventargs',
#  'hbase',
#  'receipt',
#  'provisioning',
#  'correlation',
#  'wwwroot',
#  'variant',
#  'perspective',
#  'contextmenu',
#  'alamofire',
#  'package',
#  'shiny',
#  'yuv',
#  'aws-sdk',
#  'simulate',
#  'serving',
#  'httpclient',
#  'attachment',
#  'hit',
#  'delimiter',
#  'site-packages',
#  'paragraph',
#  'finder',
#  'void',
#  'encoder',
#  'alloc',
#  'llvm',
#  'gd',
#  'vim',
#  'recreate',
#  'foreground',
#  'breakpoints',
#  'gem',
#  'sax',
#  'runtime',
#  'utility',
#  'live',
#  'nslog',
#  'fork',
#  'math',
#  'updating',
#  'tex',
#  'redefinition',
#  'xampp',
#  'toolkit',
#  'cgi',
#  'reduce',
#  'querying',
#  'pkcs',
#  'initialization',
#  'extends',
#  '.x',
#  'cakephp',
#  'menuitem',
#  'uploader',
#  'hardcode',
#  'eigen',
#  'declaration',
#  'firebase-admin',
#  'uitabbarcontroller',
#  'std',
#  'deserialization',
#  'theory',
#  'endpoint',
#  'jruby',
#  'sleep',
#  'viewport',
#  'x',
#  'nginx',
#  'backtrace',
#  'spreadsheet',
#  'console',
#  'rgba',
#  'prepare',
#  'flex',
#  'cell',
#  'wireshark',
#  'asio',
#  'wave',
#  'jersey',
#  'uicollectionviewcell',
#  'anchor',
#  'rpc',
#  'eventemitter',
#  'repository',
#  'enumeration',
#  'movieclip',
#  'teamcity',
#  'meta-inf',
#  'ionic',
#  'fopen',
#  'rsa',
#  'jinja',
#  'footer',
#  'semaphore',
#  'jsf',
#  'require',
#  'web',
#  '+',
#  'flash',
#  'ejb',
#  'websocket',
#  'javax.validation',
#  'real-time',
#  'system.drawing',
#  'vaadin',
#  'keyboard',
#  'status',
#  'basichttpbinding',
#  'setvalue',
#  'add-in',
#  'fileoutputstream',
#  'logfile',
#  'area',
#  'unicorn',
#  'hex',
#  'interface',
#  'controller',
#  'nonce',
#  'setter',
#  'fileinputstream',
#  'runnable',
#  'traversal',
#  'direction',
#  'xx',
#  'emr',
#  'transactionmanager',
#  'sorting',
#  'segue',
#  'trailing',
#  'propertyinfo',
#  'directx',
#  'notify',
#  'conda',
#  'userid',
#  'sdl',
#  'f',
#  'title',
#  'inputstream',
#  'exe',
#  'vi',
#  'webrequest',
#  'fault',
#  'perl',
#  'startup',
#  'getter',
#  'datetime',
#  'partial',
#  'ondestroy',
#  'miktex',
#  'gzip',
#  'case',
#  'alternate',
#  'unmanaged',
#  'wise',
#  'drag',
#  'crop',
#  'joomla',
#  'margin',
#  'ethernet',
#  'contenteditable',
#  'voice',
#  'spinner',
#  'virtualbox',
#  'uname',
#  'hresult',
#  'lang',
#  'filtering',
#  'transparency',
#  'locate',
#  'highlight',
#  'rename',
#  'stuff',
#  'composite',
#  'bufferedreader',
#  '.js',
#  'sqlexception',
#  'beacon',
#  'tesseract',
#  'getattr',
#  'retrofit',
#  'directory',
#  'par',
#  'react-dom',
#  'relational',
#  'arabic',
#  'sqrt',
#  'bullet',
#  'webkit',
#  'predicate',
#  'lstm',
#  'deque',
#  'tabindex',
#  'signature',
#  'ld',
#  'jstl',
#  'ckeditor',
#  'decltype',
#  'encoding',
#  'nan',
#  'yield',
#  'trunk',
#  'href',
#  'vault',
#  'nokogiri',
#  'slf',
#  'exception',
#  'mamp',
#  'processing',
#  'glob',
#  'textinput',
#  'treenode',
#  'map',
#  'difference',
#  'package.json',
#  'solr',
#  'flatten',
#  'kernel',
#  'asynccallback',
#  'helper',
#  'rule',
#  'position',
#  'jbutton',
#  'telnet',
#  'jsonresponse',
#  'red',
#  'lib',
#  'openssl',
#  'easyrtc',
#  'restore',
#  'setcookie',
#  'checked',
#  'fragmentmanager',
#  'datasource',
#  'stopwatch',
#  'system.configuration',
#  'memorystream',
#  'printing',
#  'ajp',
#  'caption',
#  'kerberos',
#  'profile',
#  'shadow',
#  'identifier',
#  'expansion',
#  'ipv',
#  'viewchild',
#  'jython',
#  'git',
#  'httpurlconnection',
#  'temp',
#  'hadoop',
#  'time',
#  'vpn',
#  'searchbar',
#  'scrapy',
#  'solaris',
#  'platform',
#  'scrollview',
#  'gtk',
#  'join',
#  'cache-control',
#  'photo',
#  'pseudocode',
#  'device-width',
#  'sqldatareader',
#  'wireless',
#  'fuzzy',
#  'daemon',
#  'encode',
#  'jupyter',
#  'graph',
#  'nsobject',
#  'vps',
#  'syswow',
#  'edit',
#  'mongoose',
#  'dump',
#  'identify',
#  'view',
#  'hue',
#  'adapter',
#  'textarea',
#  'gmail',
#  'keyerror',
#  'fft',
#  'beta',
#  'requirements.txt',
#  'mfc',
#  'mozilla',
#  'gettype',
#  'gcc',
#  'unzip',
#  'trim',
#  'recompile',
#  'intercept',
#  'relativesource',
#  '.xml',
#  'nunit',
#  'onerror',
#  'xsd',
#  'prototype',
#  'uikit',
#  'express',
#  'share',
#  'pid',
#  'cython',
#  'signed',
#  'memcached',
#  'jtextarea',
#  'automation',
#  'powershell',
#  'browser',
#  'paint',
#  'nightmare',
#  'outlet',
#  'mage',
#  'palette',
#  'iterator',
#  'api',
#  'terminal',
#  'extend',
#  'contact',
#  'strip',
#  'frame',
#  'docx',
#  'timespan',
#  'client',
#  'eventtrigger',
#  'dockerfile',
#  'observablecollection',
#  'webclient',
#  'subquery',
#  'system.text',
#  'parquet',
#  'enzyme',
#  'separator',
#  'n',
#  'transmission',
#  'nsurl',
#  'service',
#  'jquery',
#  'ping',
#  'subdirectory',
#  'user-agent',
#  'orange',
#  'buffering',
#  'intranet',
#  'generator',
#  'cryptography',
#  'pwd',
#  'undefined',
#  'screen',
#  'cat',
#  'xacml',
#  'add-on',
#  'carousel',
#  'ninject',
#  'allocator',
#  'interpolation',
#  'selection',
#  'listview',
#  'strlen',
#  'key',
#  'uiimagepickercontroller',
#  'auto',
#  'admin',
#  'stringbuffer',
#  'java',
#  'wikipedia',
#  'id',
#  'undo',
#  'legend',
#  'lightbox',
#  'deflate',
#  'remoting',
#  'onclicklistener',
#  'locking',
#  'jtable',
#  'cultureinfo',
#  'airflow',
#  'setup.py',
#  'ram',
#  'wamp',
#  'ml',
#  'runtimeexception',
#  'typeid',
#  'device',
#  'avatar',
#  'wicket',
#  'overlapping',
#  'draw',
#  'hikaricp',
#  'ttl',
#  'settimeout',
#  'arraylist',
#  'subnet',
#  'vpc',
#  'staticresource',
#  'handler',
#  'css-loader',
#  'iteration',
#  'root',
#  'transparent',
#  'app',
#  'binding',
#  'getstring',
#  'feedback',
#  'cut',
#  'transfer',
#  'collation',
#  'actionscript',
#  'material-ui',
#  'expo',
#  'double',
#  'datepicker',
#  'continue',
#  'dbconnection',
#  'push',
#  'systemd',
#  'locationmanager',
#  'accordion',
#  'pyqt',
#  'nameerror',
#  'instant',
#  'postman',
#  'big',
#  'glassfish',
#  'ansible',
#  'datacontract',
#  'dpi',
#  'url-pattern',
#  'similarity',
#  'uiviewcontroller',
#  'role',
#  'mariadb',
#  'axios',
#  'subtotal',
#  'ioctl',
#  'datamember',
#  'appender',
#  'tar',
#  'payment',
#  'qlabel',
#  'format',
#  'findall',
#  'enums',
#  'background',
#  'capybara',
#  'initializer',
#  'tooltip',
#  'wpf',
#  'jsr',
#  'serversocket',
#  'isenabled',
#  'apollo',
#  'urn',
#  '.htaccess',
#  'dynamic',
#  'slice',
#  'vagrant',
#  'layer',
#  'resolve',
#  'wc',
#  'cmp',
#  'headless',
#  'pull',
#  'happy',
#  'reshape',
#  '.doc',
#  'objectmapper',
#  'nested',
#  'destroy',
#  'suffix',
#  'md',
#  'ogg',
#  'celery',
#  'drawerlayout',
#  'webhttpbinding',
#  'datastore',
#  'backcolor',
#  'addition',
#  'conditional',
#  'bind',
#  'redis',
#  'build.gradle',
#  'laravel',
#  'prefix',
#  'servlet-mapping',
#  'autorelease',
#  'embed',
#  'adobe',
#  'formatting',
#  'lnk',
#  'abc',
#  'deadlock',
#  'singleton',
#  'web.xml',
#  'function',
#  'woff',
#  'timeline',
#  'salt',
#  'lisp',
#  'rest',
#  'wait',
#  'rpm',
#  'shrink',
#  'q',
#  'uart',
#  'prediction',
#  'wildfly',
#  'dotenv',
#  'p',
#  'tuples',
#  'notnull',
#  'timezone',
#  'offset',
#  'solver',
#  'tracking',
#  'clone',
#  'security',
#  'webview',
#  'edt',
#  'motion',
#  'wcf',
#  'comp',
#  'jms',
#  'bytecode',
#  'zone',
#  'computation',
#  'simulator',
#  'nvarchar',
#  'ingres',
#  'hashmap',
#  'continuous',
#  'load',
#  'slash',
#  'boot',
#  'mainframe',
#  'loading',
#  'core',
#  'schema',
#  'glm',
#  'nullpointerexception',
#  'show',
#  'openshift',
#  'rendering',
#  'xmlserializer',
#  'future',
#  'raise',
#  'typo',
#  'gp',
#  'swing',
#  'atlas',
#  'percentage',
#  'schannel',
#  'cl',
#  'artifact',
#  'timer',
#  'vector',
#  'replication',
#  'subscribe',
#  'populate',
#  'synchronized',
#  'hierarchy',
#  'stroke',
#  'border',
#  'transformation',
#  'random',
#  'amd',
#  'winforms',
#  'pythonpath',
#  'textbox',
#  'string.format',
#  '.json',
#  'principal',
#  'universal',
#  'onstart',
#  'word',
#  'publishing',
#  'key-value',
#  'angular-cli',
#  'phpmyadmin',
#  ...}

# %%
too_freq_words = [w for w in list_most_freq_words[:300] if w not in elems_not_to_drop_high_freq]
len(too_freq_words)
# Out:
# 135

# %%
too_freq_words
# Out:
# ['first',
#  'px',
#  'could',
#  'something',
#  'working',
#  'column',
#  'info',
#  'change',
#  'thanks',
#  'const',
#  'however',
#  'found',
#  'main',
#  'org.apache',
#  'content',
#  'org.springframework',
#  'number',
#  'query',
#  'update',
#  'used',
#  'style',
#  'issue',
#  'source',
#  'event',
#  'library',
#  'let',
#  'print',
#  'two',
#  'dependency',
#  'running',
#  'able',
#  'link',
#  'start',
#  'look',
#  'different',
#  'override',
#  'please',
#  'read',
#  'program',
#  'fine',
#  'right',
#  'password',
#  'created',
#  'li',
#  'getting',
#  'access',
#  'thread',
#  'without',
#  'possible',
#  'body',
#  'seems',
#  'another',
#  'context',
#  'idea',
#  'def',
#  'still',
#  'variable',
#  'span',
#  'open',
#  'second',
#  'component',
#  'index',
#  'cannot',
#  'anyone',
#  'usr',
#  'thing',
#  'even',
#  'parameter',
#  'order',
#  'sure',
#  'none',
#  'failed',
#  'artifactid',
#  'simple',
#  'node',
#  'groupid',
#  'check',
#  'wrong',
#  'home',
#  '.org',
#  'done',
#  'username',
#  'address',
#  'called',
#  'part',
#  'inside',
#  '.jar',
#  'debug',
#  'xmlns',
#  'already',
#  'information',
#  'instead',
#  'resource',
#  'tag',
#  '.internal',
#  'compile',
#  'etc',
#  'control',
#  'write',
#  'since',
#  'every',
#  'give',
#  'answer',
#  'long',
#  'current',
#  'added',
#  'think',
#  'well',
#  'catch',
#  'custom',
#  'folder',
#  'say',
#  'implement',
#  'install',
#  'left',
#  'java.lang',
#  'really',
#  'th',
#  'currently',
#  'login',
#  'via',
#  'top',
#  'bean',
#  'img',
#  'many',
#  'loop',
#  'container',
#  'may',
#  'br',
#  'last',
#  'child',
#  'correct',
#  '.release',
#  'note',
#  'err']

# %%
list_to_remove = ['px','query','dependency','password','access','thread','library','loop','img','login','java.lang','xmlns','.jar','node']
for word in list_to_remove:
    too_freq_words.remove(word)
too_freq_words
# Out:
# ['first',
#  'could',
#  'something',
#  'working',
#  'column',
#  'info',
#  'change',
#  'thanks',
#  'const',
#  'however',
#  'found',
#  'main',
#  'org.apache',
#  'content',
#  'org.springframework',
#  'number',
#  'update',
#  'used',
#  'style',
#  'issue',
#  'source',
#  'event',
#  'let',
#  'print',
#  'two',
#  'running',
#  'able',
#  'link',
#  'start',
#  'look',
#  'different',
#  'override',
#  'please',
#  'read',
#  'program',
#  'fine',
#  'right',
#  'created',
#  'li',
#  'getting',
#  'without',
#  'possible',
#  'body',
#  'seems',
#  'another',
#  'context',
#  'idea',
#  'def',
#  'still',
#  'variable',
#  'span',
#  'open',
#  'second',
#  'component',
#  'index',
#  'cannot',
#  'anyone',
#  'usr',
#  'thing',
#  'even',
#  'parameter',
#  'order',
#  'sure',
#  'none',
#  'failed',
#  'artifactid',
#  'simple',
#  'groupid',
#  'check',
#  'wrong',
#  'home',
#  '.org',
#  'done',
#  'username',
#  'address',
#  'called',
#  'part',
#  'inside',
#  'debug',
#  'already',
#  'information',
#  'instead',
#  'resource',
#  'tag',
#  '.internal',
#  'compile',
#  'etc',
#  'control',
#  'write',
#  'since',
#  'every',
#  'give',
#  'answer',
#  'long',
#  'current',
#  'added',
#  'think',
#  'well',
#  'catch',
#  'custom',
#  'folder',
#  'say',
#  'implement',
#  'install',
#  'left',
#  'really',
#  'th',
#  'currently',
#  'via',
#  'top',
#  'bean',
#  'many',
#  'container',
#  'may',
#  'br',
#  'last',
#  'child',
#  'correct',
#  '.release',
#  'note',
#  'err']

# %%
list = ['x','b','.a','#a','#aaa','#_','f','+','e','return','n','u','y']
for word in list:
 too_freq_words.append(word)

# %%
too_freq_words
# Out:
# ['first',
#  'could',
#  'something',
#  'working',
#  'column',
#  'info',
#  'change',
#  'thanks',
#  'const',
#  'however',
#  'found',
#  'main',
#  'org.apache',
#  'content',
#  'org.springframework',
#  'number',
#  'update',
#  'used',
#  'style',
#  'issue',
#  'source',
#  'event',
#  'let',
#  'print',
#  'two',
#  'running',
#  'able',
#  'link',
#  'start',
#  'look',
#  'different',
#  'override',
#  'please',
#  'read',
#  'program',
#  'fine',
#  'right',
#  'created',
#  'li',
#  'getting',
#  'without',
#  'possible',
#  'body',
#  'seems',
#  'another',
#  'context',
#  'idea',
#  'def',
#  'still',
#  'variable',
#  'span',
#  'open',
#  'second',
#  'component',
#  'index',
#  'cannot',
#  'anyone',
#  'usr',
#  'thing',
#  'even',
#  'parameter',
#  'order',
#  'sure',
#  'none',
#  'failed',
#  'artifactid',
#  'simple',
#  'groupid',
#  'check',
#  'wrong',
#  'home',
#  '.org',
#  'done',
#  'username',
#  'address',
#  'called',
#  'part',
#  'inside',
#  'debug',
#  'already',
#  'information',
#  'instead',
#  'resource',
#  'tag',
#  '.internal',
#  'compile',
#  'etc',
#  'control',
#  'write',
#  'since',
#  'every',
#  'give',
#  'answer',
#  'long',
#  'current',
#  'added',
#  'think',
#  'well',
#  'catch',
#  'custom',
#  'folder',
#  'say',
#  'implement',
#  'install',
#  'left',
#  'really',
#  'th',
#  'currently',
#  'via',
#  'top',
#  'bean',
#  'many',
#  'container',
#  'may',
#  'br',
#  'last',
#  'child',
#  'correct',
#  '.release',
#  'note',
#  'err',
#  'x',
#  'b',
#  '.a',
#  '#a',
#  '#aaa',
#  '#_',
#  'f',
#  '+',
#  'e',
#  'return',
#  'n',
#  'u',
#  'y']

# %%
df
# Out:
#                                                    Title  \
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3               managing data access simple winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation currently pr...
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .internal .resolve .artifactnotfoun...
#
#                                                     Body  \
# 0      way sandbox linux process certain directory gi...
# 1      jframe two panel one panel draw line working m...
# 2      expert network security pardon question smart ...
# 3      simple winforms data entry app us sqlite alway...
# 4      basic node.js app trying get ground using expr...
# ...                                                  ...
# 49995  using ssis tool ole db downloading data vertic...
# 49996  using f uploading file already created bucket ...
# 49997  following jupyter notebook course hit upon err...
# 49998  json wanted update field process my-process po...
# 49999  using version firebase google play service bui...
#
#                                                     Tags  \
# 0                   linux ubuntu process sandbox selinux
# 1                      java graphics jframe jpanel paint
# 2        security ssh ssh-keys openssh man-in-the-middle
# 3             c# winforms sqlite datatable sqlconnection
# 4                javascript html node.js mongodb express
# ...                                                  ...
# 49995  sql-server ssas oledb sql-server-data-tools ve...
# 49996  python amazon-web-services amazon-s boto pytho...
# 49997  python machine-learning deep-learning pytorch ...
# 49998               java json rest json-patch http-patch
# 49999  android android-studio android-gradle-plugin g...
#
#                                              _clean_tags  _len_body  \
# 0             [linux, ubuntu, process, sandbox, selinux]        526
# 1                [java, graphics, jframe, jpanel, paint]       2969
# 2      [security, ssh, ssh-keys, openssh, man-in-the-...        447
# 3       [c#, winforms, sqlite, datatable, sqlconnection]       2537
# 4          [javascript, html, node.js, mongodb, express]        335
# ...                                                  ...        ...
# 49995  [sql-server, ssas, oledb, sql-server-data-tool...        206
# 49996  [python, amazon-web-services, amazon-s, boto, ...        301
# 49997  [python, machine-learning, deep-learning, pyto...        908
# 49998         [java, json, rest, json-patch, http-patch]        645
# 49999  [android, android-studio, android-gradle-plugi...      27209
#
#                                                   Body_2  _len_body_2
# 0      sandbox linux process certain directory give p...          462
# 1      jframe two panel panel draw line working minim...         2855
# 2      expert network security pardon smart automatin...          414
# 3      simple winforms entry app u sqlite always sing...         2382
# 4      basic node.js app get ground express framework...          292
# ...                                                  ...          ...
# 49995  ssis tool ole db downloading vertica database ...          186
# 49996  f uploading file already created bucket deleti...          268
# 49997  jupyter notebook course hit upon line cnn_lear...          781
# 49998  json wanted update field process my-process po...          566
# 49999  version firebase google play service build sta...        27143
#
# [50000 rows x 7 columns]

# %%
df['Body_3'] = df['Body_2'].parallel_apply(lambda x : final_clean_2(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df['Title_2'] = df['Title'].parallel_apply(lambda x : final_clean_2(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8334), Label(value='0 / 8334'))), …

# %%
df
# Out:
#                                                    Title  \
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3               managing data access simple winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation currently pr...
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .internal .resolve .artifactnotfoun...
#
#                                                     Body  \
# 0      way sandbox linux process certain directory gi...
# 1      jframe two panel one panel draw line working m...
# 2      expert network security pardon question smart ...
# 3      simple winforms data entry app us sqlite alway...
# 4      basic node.js app trying get ground using expr...
# ...                                                  ...
# 49995  using ssis tool ole db downloading data vertic...
# 49996  using f uploading file already created bucket ...
# 49997  following jupyter notebook course hit upon err...
# 49998  json wanted update field process my-process po...
# 49999  using version firebase google play service bui...
#
#                                                     Tags  \
# 0                   linux ubuntu process sandbox selinux
# 1                      java graphics jframe jpanel paint
# 2        security ssh ssh-keys openssh man-in-the-middle
# 3             c# winforms sqlite datatable sqlconnection
# 4                javascript html node.js mongodb express
# ...                                                  ...
# 49995  sql-server ssas oledb sql-server-data-tools ve...
# 49996  python amazon-web-services amazon-s boto pytho...
# 49997  python machine-learning deep-learning pytorch ...
# 49998               java json rest json-patch http-patch
# 49999  android android-studio android-gradle-plugin g...
#
#                                              _clean_tags  _len_body  \
# 0             [linux, ubuntu, process, sandbox, selinux]        526
# 1                [java, graphics, jframe, jpanel, paint]       2969
# 2      [security, ssh, ssh-keys, openssh, man-in-the-...        447
# 3       [c#, winforms, sqlite, datatable, sqlconnection]       2537
# 4          [javascript, html, node.js, mongodb, express]        335
# ...                                                  ...        ...
# 49995  [sql-server, ssas, oledb, sql-server-data-tool...        206
# 49996  [python, amazon-web-services, amazon-s, boto, ...        301
# 49997  [python, machine-learning, deep-learning, pyto...        908
# 49998         [java, json, rest, json-patch, http-patch]        645
# 49999  [android, android-studio, android-gradle-plugi...      27209
#
#                                                   Body_2  _len_body_2  \
# 0      sandbox linux process certain directory give p...          462
# 1      jframe two panel panel draw line working minim...         2855
# 2      expert network security pardon smart automatin...          414
# 3      simple winforms entry app u sqlite always sing...         2382
# 4      basic node.js app get ground express framework...          292
# ...                                                  ...          ...
# 49995  ssis tool ole db downloading vertica database ...          186
# 49996  f uploading file already created bucket deleti...          268
# 49997  jupyter notebook course hit upon line cnn_lear...          781
# 49998  json wanted update field process my-process po...          566
# 49999  version firebase google play service build sta...        27143
#
#                                                   Body_3  \
# 0      sandbox linux process certain directory proces...
# 1      jframe panel panel draw line minimized window ...
# 2      expert network security pardon smart automatin...
# 3      winforms entry app sqlite always single-user a...
# 4      basic node.js app get ground express framework...
# ...                                                  ...
# 49995  ssis tool ole db downloading vertica database ...
# 49996  uploading file bucket deleting bucket executio...
# 49997  jupyter notebook course hit upon line cnn_lear...
# 49998  json wanted field process my-process pod some-...
# 49999  version firebase google play service build sta...
#
#                                                  Title_2
# 0      giving unix process exclusive rw access directory
# 1                    automatic repaint minimizing window
# 2      man-in-the-middle attack security threat ssh a...
# 3                      managing data access winforms app
# 4                                 render basic html view
# ...                                                  ...
# 49995  bypass vertica error execution time exceeded r...
# 49996  conflicting conditional operation progress bucket
# 49997              problem lr_find pytorch fastai course
# 49998              jsonpatch escape slash jsonpatch+json
# 49999  org.gradle .resolve .artifactnotfoundexception...
#
# [50000 rows x 9 columns]

# %%
df.to_csv("data/cleaned/df_process_text_3.csv", index=False)

# %%
import matplotlib.pyplot as plt
wordcloud = WordCloud(background_color='white',
                      stopwords=[],
                      max_words=50).generate(" ".join(raw_tokens_text))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
wordcloud = WordCloud(background_color='white',
                      stopwords=[],
                      max_words=50).generate(" ".join(raw_tokens_tags))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
